# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import funciones_estadistica as estadistica
import pymysql
from sqlalchemy import create_engine, text
import ast  # Para convertir texto en listas de Python

# %%
pip install word2number
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: word2number in c:\users\lidia\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from word2number import w2n

# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
import funciones_limpieza as limp
import funciones_visualizacion as visual

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Fase 1. Análisis exploratorio de datos (EDA).

# %%
df = pd.read_csv("hr_raw_data.csv")

# %%
def exploracion_basica(df):
    print("Primeras filas:")
    display(df.head())
    
    print("\nDimensiones del DataFrame:")
    print(df.shape)
    
    print("\nTipos de datos:")
    print(df.dtypes)
    
    print("\nValores únicos por columna:")
    print(df.nunique())

    print("\nValores Nulos")
    print(df.isnull().sum())

    print("\nValores Duplicados")
    print(df.duplicated().sum())
    


print (exploracion_basica(df))
# Out:
# Primeras filas:
#    Unnamed: 0 age attrition businesstravel    dailyrate  \
# 0           0  51        No            NaN  2015.722222
# 1           1  52        No            NaN  2063.388889
# 2           2  42        No  travel_rarely  1984.253968
# 3           3  47        No  travel_rarely  1771.404762
# 4           4  46        No            NaN  1582.771346
#
#                  department  distancefromhome  education    educationfield  \
# 0                       NaN                 6          3               NaN
# 1                       NaN                 1          4     Life Sciences
# 2   Research & Development                  4          2  Technical Degree
# 3                       NaN                 2          4           Medical
# 4                       NaN                 3          3  Technical Degree
#
#    employeecount  employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0              1               1                        1       0         NaN
# 1              1               2                        3       0         NaN
# 2              1               3                        3       0         NaN
# 3              1               4                        1       1         NaN
# 4              1               5                        1       1         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   resEArch DIREcToR                 3
# 1               2         5             ManAGeR                 3
# 2               3         5             ManaGER                 4
# 3               3         4   ReseArCH DIrECtOr                 3
# 4               4         4     sAleS EXECUtIve                 1
#
#   maritalstatus monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# 0           NaN     16280,83$   42330,17$                   7      Y       No
# 1           NaN           NaN   43331,17$                   0    NaN      NaN
# 2       Married           NaN   41669,33$                   1    NaN       No
# 3       Married     14307,50$   37199,50$                   3      Y      NaN
# 4      Divorced     12783,92$   33238,20$                   2      Y       No
#
#    percentsalaryhike performancerating  relationshipsatisfaction  \
# 0                 13               3,0                         3
# 1                 14               3,0                         1
# 2                 11               3,0                         4
# 3                 19               3,0                         2
# 4                 12               3,0                         4
#
#   standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 0     Full Time                 0               NaN                      5
# 1           NaN                 1              34,0                      5
# 2           NaN                 0              22,0                      3
# 3     Full Time                 2               NaN                      2
# 4           NaN                 1               NaN                      5
#
#   worklifebalance  yearsatcompany yearsincurrentrole  yearssincelastpromotion  \
# 0             3,0              20                NaN                       15
# 1             3,0              33                NaN                       11
# 2             NaN              22                NaN                       11
# 3             NaN              20                NaN                        5
# 4             3,0              19                NaN                        2
#
#    yearswithcurrmanager sameasmonthlyincome  datebirth      salary  \
# 0                    15           16280,83$       1972  195370,00$
# 1                     9                 NaN       1971  199990,00$
# 2                    15                 NaN       1981  192320,00$
# 3                     6           14307,50$       1976  171690,00$
# 4                     8           12783,92$       1977         NaN
#
#                         roledepartament  numberchildren remotework
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0
# Dimensiones del DataFrame:
# (1678, 42)
#
# Tipos de datos:
# Unnamed: 0                    int64
# age                          object
# attrition                    object
# businesstravel               object
# dailyrate                   float64
# department                   object
# distancefromhome              int64
# education                     int64
# educationfield               object
# employeecount                 int64
# employeenumber                int64
# environmentsatisfaction       int64
# gender                        int64
# hourlyrate                  float64
# jobinvolvement                int64
# joblevel                      int64
# jobrole                      object
# jobsatisfaction               int64
# maritalstatus                object
# monthlyincome                object
# monthlyrate                  object
# numcompaniesworked            int64
# over18                       object
# overtime                     object
# percentsalaryhike             int64
# performancerating            object
# relationshipsatisfaction      int64
# standardhours                object
# stockoptionlevel              int64
# totalworkingyears            object
# trainingtimeslastyear         int64
# worklifebalance              object
# yearsatcompany                int64
# yearsincurrentrole           object
# yearssincelastpromotion       int64
# yearswithcurrmanager          int64
# sameasmonthlyincome          object
# datebirth                     int64
# salary                       object
# roledepartament              object
# numberchildren              float64
# remotework                   object
# dtype: object
#
# Valores únicos por columna:
# Unnamed: 0                  1678
# age                           54
# attrition                      2
# businesstravel                 3
# dailyrate                    673
# department                     3
# distancefromhome              69
# education                      5
# educationfield                 6
# employeecount                  1
# employeenumber              1614
# environmentsatisfaction       38
# gender                         2
# hourlyrate                   194
# jobinvolvement                 4
# joblevel                       5
# jobrole                     1579
# jobsatisfaction                4
# maritalstatus                  5
# monthlyincome                493
# monthlyrate                  673
# numcompaniesworked            10
# over18                         1
# overtime                       2
# percentsalaryhike             15
# performancerating              2
# relationshipsatisfaction       4
# standardhours                  2
# stockoptionlevel               4
# totalworkingyears             40
# trainingtimeslastyear          7
# worklifebalance                4
# yearsatcompany                37
# yearsincurrentrole            10
# yearssincelastpromotion       16
# yearswithcurrmanager          18
# sameasmonthlyincome          493
# datebirth                     43
# salary                       583
# roledepartament              301
# numberchildren                 0
# remotework                     5
# dtype: int64
#
# Valores Nulos
# Unnamed: 0                     0
# age                            0
# attrition                      0
# businesstravel               801
# dailyrate                      0
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeecount                  0
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# hourlyrate                  1267
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# monthlyincome                489
# monthlyrate                    0
# numcompaniesworked             0
# over18                       938
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# totalworkingyears            549
# trainingtimeslastyear          0
# worklifebalance              114
# yearsatcompany                 0
# yearsincurrentrole          1643
# yearssincelastpromotion        0
# yearswithcurrmanager           0
# sameasmonthlyincome          489
# datebirth                      0
# salary                       285
# roledepartament             1366
# numberchildren              1678
# remotework                     0
# dtype: int64
#
# Valores Duplicados
# 0
# None

# %%
nulos = df.isnull().sum()/df.shape[0]*100
# nulos ordenados de mayor a menor
nulos.sort_values(ascending=False)
# Out:
# numberchildren              100.000000
# yearsincurrentrole           97.914184
# department                   81.406436
# roledepartament              81.406436
# hourlyrate                   75.506555
# over18                       55.899881
# businesstravel               47.735399
# educationfield               46.126341
# overtime                     41.477950
# maritalstatus                40.226460
# totalworkingyears            32.717521
# monthlyincome                29.141836
# sameasmonthlyincome          29.141836
# standardhours                20.917759
# salary                       16.984505
# performancerating            11.918951
# worklifebalance               6.793802
# Unnamed: 0                    0.000000
# employeecount                 0.000000
# education                     0.000000
# distancefromhome              0.000000
# dailyrate                     0.000000
# attrition                     0.000000
# age                           0.000000
# environmentsatisfaction       0.000000
# employeenumber                0.000000
# percentsalaryhike             0.000000
# numcompaniesworked            0.000000
# monthlyrate                   0.000000
# gender                        0.000000
# jobinvolvement                0.000000
# joblevel                      0.000000
# jobrole                       0.000000
# jobsatisfaction               0.000000
# yearsatcompany                0.000000
# trainingtimeslastyear         0.000000
# relationshipsatisfaction      0.000000
# stockoptionlevel              0.000000
# datebirth                     0.000000
# yearswithcurrmanager          0.000000
# yearssincelastpromotion       0.000000
# remotework                    0.000000
# dtype: float64

# %%
df.drop(columns=["monthlyincome", "employeecount", "hourlyrate", "monthlyrate", "dailyrate", "datebirth", "numberchildren","yearsincurrentrole", "sameasmonthlyincome","over18","Unnamed: 0"], inplace=True)

# %%
df["education"] = df["education"].astype(object)

# %% [markdown]
# Gestión de nulos y limpieza: overtime, marital status, totalworkingyears, standardhours, worklifebalance

# %%
df.head()
# Out:
#   age attrition businesstravel                department  distancefromhome  \
# 0  51        No            NaN                       NaN                 6
# 1  52        No            NaN                       NaN                 1
# 2  42        No  travel_rarely   Research & Development                  4
# 3  47        No  travel_rarely                       NaN                 2
# 4  46        No            NaN                       NaN                 3
#
#   education    educationfield  employeenumber  environmentsatisfaction  \
# 0         3               NaN               1                        1
# 1         4     Life Sciences               2                        3
# 2         2  Technical Degree               3                        3
# 3         4           Medical               4                        1
# 4         3  Technical Degree               5                        1
#
#    gender  jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0       0               3         5   resEArch DIREcToR                 3
# 1       0               2         5             ManAGeR                 3
# 2       0               3         5             ManaGER                 4
# 3       1               3         4   ReseArCH DIrECtOr                 3
# 4       1               4         4     sAleS EXECUtIve                 1
#
#   maritalstatus  numcompaniesworked overtime  percentsalaryhike  \
# 0           NaN                   7       No                 13
# 1           NaN                   0      NaN                 14
# 2       Married                   1       No                 11
# 3       Married                   3      NaN                 19
# 4      Divorced                   2       No                 12
#
#   performancerating  relationshipsatisfaction standardhours  stockoptionlevel  \
# 0               3,0                         3     Full Time                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2     Full Time                 2
# 4               3,0                         4           NaN                 1
#
#   totalworkingyears  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
#
#    yearssincelastpromotion  yearswithcurrmanager      salary  \
# 0                       15                    15  195370,00$
# 1                       11                     9  199990,00$
# 2                       11                    15  192320,00$
# 3                        5                     6  171690,00$
# 4                        2                     8         NaN
#
#                         roledepartament remotework
# 0                                   NaN        Yes
# 1                                   NaN          1
# 2   ManaGER  -  Research & Development           1
# 3                                   NaN      False
# 4                                   NaN          0

# %%
print(df.shape)
# Out:
# (1678, 31)

# %%
for col in df.select_dtypes(include='number'):
    print('-----------------------------')
    print(f"La distribución de las categorías para la columna {col.upper()}")
    print(df[col].nunique())
    print(df[col].value_counts(normalize=True))
# Out:
# -----------------------------
# La distribución de las categorías para la columna DISTANCEFROMHOME
# 69
# distancefromhome
#  2     0.135876
#  1     0.124553
#  9     0.053039
#  10    0.051251
#  8     0.050656
#          ...
# -21    0.001192
# -43    0.001192
# -28    0.001192
# -39    0.000596
# -40    0.000596
# Name: proportion, Length: 69, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna EMPLOYEENUMBER
# 1614
# employeenumber
# 300     0.001192
# 168     0.001192
# 644     0.001192
# 271     0.001192
# 663     0.001192
#           ...
# 1578    0.000596
# 1579    0.000596
# 1580    0.000596
# 1581    0.000596
# 1614    0.000596
# Name: proportion, Length: 1614, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna ENVIRONMENTSATISFACTION
# 38
# environmentsatisfaction
# 4     0.287843
# 3     0.280691
# 2     0.188319
# 1     0.182360
# 12    0.004172
# 35    0.004172
# 13    0.003576
# 14    0.003576
# 47    0.002980
# 24    0.002980
# 41    0.002384
# 42    0.002384
# 46    0.002384
# 36    0.002384
# 48    0.002384
# 20    0.001788
# 22    0.001788
# 11    0.001788
# 18    0.001788
# 45    0.001788
# 27    0.001788
# 25    0.001788
# 17    0.001788
# 37    0.001192
# 38    0.001192
# 16    0.001192
# 31    0.001192
# 15    0.001192
# 19    0.001192
# 29    0.001192
# 28    0.000596
# 33    0.000596
# 21    0.000596
# 39    0.000596
# 49    0.000596
# 10    0.000596
# 26    0.000596
# 43    0.000596
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna GENDER
# 2
# gender
# 0    0.601311
# 1    0.398689
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna JOBINVOLVEMENT
# 4
# jobinvolvement
# 3    0.592968
# 2    0.250894
# 4    0.101311
# 1    0.054827
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna JOBLEVEL
# 5
# joblevel
# 2    0.368296
# 1    0.364720
# 3    0.151967
# 4    0.067938
# 5    0.047080
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna JOBSATISFACTION
# 4
# jobsatisfaction
# 4    0.320620
# 3    0.296186
# 1    0.194279
# 2    0.188915
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna NUMCOMPANIESWORKED
# 10
# numcompaniesworked
# 1    0.355781
# 0    0.139452
# 3    0.103695
# 4    0.098927
# 2    0.097139
# 7    0.052443
# 6    0.044696
# 5    0.039928
# 9    0.035161
# 8    0.032777
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna PERCENTSALARYHIKE
# 15
# percentsalaryhike
# 11    0.143623
# 13    0.142431
# 12    0.141836
# 14    0.136472
# 15    0.066746
# 18    0.060787
# 17    0.054827
# 16    0.053039
# 19    0.051251
# 22    0.036353
# 20    0.035757
# 21    0.030393
# 23    0.019666
# 24    0.015495
# 25    0.011323
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna RELATIONSHIPSATISFACTION
# 4
# relationshipsatisfaction
# 3    0.314064
# 4    0.287843
# 2    0.208582
# 1    0.189511
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna STOCKOPTIONLEVEL
# 4
# stockoptionlevel
# 0    0.428486
# 1    0.410608
# 2    0.105483
# 3    0.055423
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna TRAININGTIMESLASTYEAR
# 7
# trainingtimeslastyear
# 2    0.372467
# 3    0.331943
# 4    0.085221
# 5    0.081645
# 1    0.048272
# 6    0.042908
# 0    0.037545
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna YEARSATCOMPANY
# 37
# yearsatcompany
# 5     0.127533
# 1     0.107867
# 3     0.088796
# 2     0.086412
# 10    0.082837
# 4     0.069130
# 7     0.068534
# 8     0.067342
# 9     0.058403
# 6     0.050060
# 0     0.028010
# 11    0.022050
# 20    0.017878
# 13    0.016091
# 15    0.013111
# 14    0.011323
# 22    0.010727
# 18    0.009535
# 12    0.008939
# 21    0.008343
# 16    0.008343
# 19    0.007151
# 17    0.005364
# 24    0.004172
# 33    0.002980
# 25    0.002980
# 26    0.002384
# 36    0.002384
# 31    0.001788
# 27    0.001788
# 40    0.001788
# 32    0.001788
# 23    0.001192
# 29    0.001192
# 37    0.000596
# 30    0.000596
# 34    0.000596
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna YEARSSINCELASTPROMOTION
# 16
# yearssincelastpromotion
# 0     0.390346
# 1     0.236591
# 2     0.109058
# 7     0.056615
# 4     0.041120
# 3     0.038737
# 5     0.031585
# 6     0.022646
# 11    0.016091
# 8     0.013111
# 9     0.011323
# 15    0.009535
# 14    0.006555
# 12    0.006555
# 13    0.005959
# 10    0.004172
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna YEARSWITHCURRMANAGER
# 18
# yearswithcurrmanager
# 2     0.235399
# 0     0.169845
# 7     0.163886
# 3     0.090584
# 8     0.072706
# 4     0.064362
# 1     0.051847
# 9     0.042312
# 5     0.023242
# 10    0.019666
# 6     0.018474
# 11    0.013111
# 12    0.011919
# 13    0.010131
# 17    0.004768
# 15    0.002980
# 14    0.002980
# 16    0.001788
# Name: proportion, dtype: float64

# %%
for col in df.select_dtypes(include='object'):
    print('-----------------------------')
    print(f"La distribución de las categorías para la columna {col.upper()}")
    print(df[col].nunique())
    print(df[col].value_counts(normalize=True))
# Out:
# -----------------------------
# La distribución de las categorías para la columna AGE
# 54
# age
# 35              0.052443
# 31              0.052443
# 34              0.051251
# 29              0.048868
# 36              0.047080
# 32              0.039333
# 30              0.038737
# 38              0.038141
# 33              0.037545
# 40              0.035757
# 28              0.032181
# 37              0.032181
# 27              0.032181
# 45              0.029797
# 42              0.029797
# 41              0.028605
# 39              0.027414
# 26              0.027414
# 43              0.025030
# 46              0.022646
# 44              0.020262
# 50              0.020262
# 47              0.017878
# 24              0.017282
# 25              0.016687
# 49              0.015495
# 55              0.014899
# 51              0.013111
# 48              0.013111
# 53              0.011919
# 54              0.011919
# 52              0.010727
# 56              0.010727
# 22              0.010131
# 21              0.010131
# 58              0.009535
# 23              0.008939
# 59              0.006555
# 20              0.006555
# 18              0.005364
# 19              0.005364
# 57              0.003576
# 60              0.002980
# twenty-four     0.001192
# thirty-two      0.001192
# forty-seven     0.000596
# thirty-six      0.000596
# fifty-eight     0.000596
# fifty-two       0.000596
# thirty-one      0.000596
# thirty          0.000596
# fifty-five      0.000596
# twenty-six      0.000596
# thirty-seven    0.000596
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna ATTRITION
# 2
# attrition
# No     0.837902
# Yes    0.162098
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna BUSINESSTRAVEL
# 3
# businesstravel
# travel_rarely        0.702395
# travel_frequently    0.191562
# non-travel           0.106043
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna DEPARTMENT
# 3
# department
# Research & Development     0.650641
# Sales                      0.298077
# Human Resources            0.051282
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna EDUCATION
# 5
# education
# 3    0.386770
# 4    0.274732
# 2    0.191895
# 1    0.110846
# 5    0.035757
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna EDUCATIONFIELD
# 6
# educationfield
# Life Sciences       0.405973
# Medical             0.316372
# Marketing           0.117257
# Technical Degree    0.077434
# Other               0.069690
# Human Resources     0.013274
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna JOBROLE
# 1579
# jobrole
# mANager                       0.002980
# maNaGeR                       0.001788
# ManageR                       0.001788
# MANAgER                       0.001788
# mAnaGeR                       0.001788
#                                 ...
# human RESOurceS               0.000596
# SaLeS exEcUTiVE               0.000596
# ReSEArch scieNTiST            0.000596
# HEaLTHCArE rEpreSeNtatiVE     0.000596
# ReseaRCh dIRecTor             0.000596
# Name: proportion, Length: 1579, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna MARITALSTATUS
# 5
# maritalstatus
# Married     0.417747
# Single      0.341974
# Divorced    0.193420
# Marreid     0.035892
# divorced    0.010967
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna OVERTIME
# 2
# overtime
# No     0.727088
# Yes    0.272912
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna PERFORMANCERATING
# 2
# performancerating
# 3,0    0.850474
# 4,0    0.149526
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna STANDARDHOURS
# 2
# standardhours
# Part Time    0.698568
# Full Time    0.301432
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna TOTALWORKINGYEARS
# 40
# totalworkingyears
# 10,0    0.133747
# 6,0     0.077945
# 8,0     0.076174
# 9,0     0.062888
# 5,0     0.060230
# 7,0     0.052259
# 4,0     0.050487
# 1,0     0.048716
# 12,0    0.030115
# 3,0     0.030115
# 11,0    0.027458
# 14,0    0.027458
# 13,0    0.027458
# 16,0    0.026572
# 20,0    0.026572
# 18,0    0.024801
# 15,0    0.024801
# 21,0    0.020372
# 17,0    0.020372
# 2,0     0.018601
# 22,0    0.016829
# 19,0    0.015058
# 24,0    0.012400
# 28,0    0.012400
# 23,0    0.011515
# 0,0     0.007086
# 26,0    0.007086
# 37,0    0.006200
# 27,0    0.005314
# 29,0    0.005314
# 33,0    0.005314
# 25,0    0.005314
# 36,0    0.005314
# 40,0    0.003543
# 31,0    0.003543
# 32,0    0.002657
# 30,0    0.002657
# 35,0    0.002657
# 34,0    0.001771
# 38,0    0.000886
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna WORKLIFEBALANCE
# 4
# worklifebalance
# 3,0    0.604859
# 2,0    0.239130
# 4,0    0.103581
# 1,0    0.052430
# Name: proportion, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna SALARY
# 583
# salary
# 53914,11$     0.193826
# 28111,13$     0.183058
# 100071,84$    0.087581
# 153407,07$    0.032304
# 191324,62$    0.020101
#                 ...
# 58280,00$     0.000718
# 132120,00$    0.000718
# 27410,00$     0.000718
# 49600,00$     0.000718
# 47280,00$     0.000718
# Name: proportion, Length: 583, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna ROLEDEPARTAMENT
# 301
# roledepartament
# rESEArcH SCiEntIst  -  Research & Development            0.006410
# LABOrATOrY TEchnIcIAn  -  Research & Development         0.006410
# Sales exECutIVE  -  Sales                                0.006410
# resEaRcH scIENTiSt  -  Research & Development            0.006410
# humAN resoURCEs  -  Human Resources                      0.006410
#                                                            ...
# ManUFACtURiNg DiRECTOr  -  Research & Development        0.003205
# ResEARcH DiReCToR  -  Research & Development             0.003205
# MANAgER  -  Research & Development                       0.003205
# labORATORY TechnIcIaN  -  Research & Development         0.003205
# heaLtHcArE repResENtATiVe  -  Research & Development     0.003205
# Name: proportion, Length: 301, dtype: float64
# -----------------------------
# La distribución de las categorías para la columna REMOTEWORK
# 5
# remotework
# 1        0.223480
# True     0.215733
# False    0.189511
# 0        0.189511
# Yes      0.181764
# Name: proportion, dtype: float64

# %%
df.describe().T
# Out:
#                            count        mean         std   min     25%    50%  \
# distancefromhome          1678.0    4.504172   14.652066 -49.0    2.00    5.0
# employeenumber            1678.0  809.859952  467.084867   1.0  403.25  813.5
# environmentsatisfaction   1678.0    4.264005    6.912695   1.0    2.00    3.0
# gender                    1678.0    0.398689    0.489774   0.0    0.00    0.0
# jobinvolvement            1678.0    2.740763    0.710359   1.0    2.00    3.0
# joblevel                  1678.0    2.064362    1.099425   1.0    1.00    2.0
# jobsatisfaction           1678.0    2.743147    1.105172   1.0    2.00    3.0
# numcompaniesworked        1678.0    2.670441    2.501133   0.0    1.00    2.0
# percentsalaryhike         1678.0   15.154350    3.649607  11.0   12.00   14.0
# relationshipsatisfaction  1678.0    2.700238    1.079494   1.0    2.00    3.0
# stockoptionlevel          1678.0    0.787843    0.843252   0.0    0.00    1.0
# trainingtimeslastyear     1678.0    2.795590    1.288657   0.0    2.00    3.0
# yearsatcompany            1678.0    7.124553    6.173837   0.0    3.00    5.0
# yearssincelastpromotion   1678.0    2.241955    3.246554   0.0    0.00    1.0
# yearswithcurrmanager      1678.0    4.200238    3.554224   0.0    2.00    3.0
#
#                               75%     max
# distancefromhome            11.00    29.0
# employeenumber            1215.75  1614.0
# environmentsatisfaction      4.00    49.0
# gender                       1.00     1.0
# jobinvolvement               3.00     4.0
# joblevel                     3.00     5.0
# jobsatisfaction              4.00     4.0
# numcompaniesworked           4.00     9.0
# percentsalaryhike           18.00    25.0
# relationshipsatisfaction     4.00     4.0
# stockoptionlevel             1.00     3.0
# trainingtimeslastyear        3.00     6.0
# yearsatcompany               9.00    40.0
# yearssincelastpromotion      3.00    15.0
# yearswithcurrmanager         7.00    17.0

# %%
df.describe(include = "object").T
# Out:
#                   count unique  \
# age                1678     54
# attrition          1678      2
# businesstravel      877      3
# department          312      3
# education          1678      5
# educationfield      904      6
# jobrole            1678   1579
# maritalstatus      1003      5
# overtime            982      2
# performancerating  1478      2
# standardhours      1327      2
# totalworkingyears  1129     40
# worklifebalance    1564      4
# salary             1393    583
# roledepartament     312    301
# remotework         1678      5
#
#                                                                top  freq
# age                                                             35    88
# attrition                                                       No  1406
# businesstravel                                       travel_rarely   616
# department                                 Research & Development    203
# education                                                        3   649
# educationfield                                       Life Sciences   367
# jobrole                                                   mANager      5
# maritalstatus                                              Married   419
# overtime                                                        No   714
# performancerating                                              3,0  1257
# standardhours                                            Part Time   927
# totalworkingyears                                             10,0   151
# worklifebalance                                                3,0   946
# salary                                                   53914,11$   270
# roledepartament     rESEArcH SCiEntIst  -  Research & Development      2
# remotework                                                       1   375

# %% [markdown]
# A continuación, vemos la distribución de las distintas variables, pudiendo ver también si existen valores atípicos.

# %%
num_bins = 40
df.hist(bins=num_bins, figsize=(25,25))
plt.savefig("histogram_plots")
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['number']).columns
rows = (len(numeric_columns) // 3) + (len(numeric_columns) % 3 > 0)  # Calcula el número de filas necesarias
cols = 3

# Definir tamaño del gráfico
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(15, rows*3))
if rows > 1:
    axes = axes.flatten()
# Iterar sobre cada columna numérica y graficar un boxplot
for i, col in enumerate(numeric_columns):
    sns.boxplot(data=df[col], ax=axes[i])
    axes[i].set_title(f"Boxplot de {col}")

# Ajustar el layout para evitar solapamientos
plt.tight_layout()
plt.show()

# %% [markdown]
# # Limpieza

# %%
visual.extract_data(df)
# Out:
# INFORMACIÓN SOBRE COLUMNAS
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1678 entries, 0 to 1677
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   department                312 non-null    object
#  4   distancefromhome          1678 non-null   int64
#  5   education                 1678 non-null   object
#  6   educationfield            904 non-null    object
#  7   employeenumber            1678 non-null   int64
#  8   environmentsatisfaction   1678 non-null   int64
#  9   gender                    1678 non-null   int64
#  10  jobinvolvement            1678 non-null   int64
#  11  joblevel                  1678 non-null   int64
#  12  jobrole                   1678 non-null   object
#  13  jobsatisfaction           1678 non-null   int64
#  14  maritalstatus             1003 non-null   object
#  15  numcompaniesworked        1678 non-null   int64
#  16  overtime                  982 non-null    object
#  17  percentsalaryhike         1678 non-null   int64
#  18  performancerating         1478 non-null   object
#  19  relationshipsatisfaction  1678 non-null   int64
#  20  standardhours             1327 non-null   object
#  21  stockoptionlevel          1678 non-null   int64
#  22  totalworkingyears         1129 non-null   object
#  23  trainingtimeslastyear     1678 non-null   int64
#  24  worklifebalance           1564 non-null   object
#  25  yearsatcompany            1678 non-null   int64
#  26  yearssincelastpromotion   1678 non-null   int64
#  27  yearswithcurrmanager      1678 non-null   int64
#  28  salary                    1393 non-null   object
#  29  roledepartament           312 non-null    object
#  30  remotework                1678 non-null   object
# dtypes: int64(15), object(16)
# memory usage: 406.5+ KB
# None
#
# --------------------------------------------------
#
# VISUALIZACIÓN DE NULOS
#
# age                            0
# attrition                      0
# businesstravel               801
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# numcompaniesworked             0
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# totalworkingyears            549
# trainingtimeslastyear          0
# worklifebalance              114
# yearsatcompany                 0
# yearssincelastpromotion        0
# yearswithcurrmanager           0
# salary                       285
# roledepartament             1366
# remotework                     0
# dtype: int64
#
# VISUALIZACIÓN DE ÚNICOS
#
# age
# -----------------------------
# ['51' '52' '42' '47' '46' '48' '59' '41' '56' '38' '55' '40' '58' '35'
#  '45' '33' '36' '34' 'forty-seven' '53' '43' '60' '32' '37' '49' '39' '50'
#  '44' '30' 'fifty-eight' '29' '31' '54' '57' '27' 'thirty-six' '28' '26'
#  'fifty-five' '25' 'fifty-two' 'thirty-one' '24' 'thirty' '23' '22' '21'
#  '20' 'twenty-six' '19' 'thirty-seven' '18' 'thirty-two' 'twenty-four']
# attrition
# -----------------------------
# ['No' 'Yes']
# businesstravel
# -----------------------------
# [nan 'travel_rarely' 'travel_frequently' 'non-travel']
# department
# -----------------------------
# [nan ' Research & Development ' ' Sales ' ' Human Resources ']
# education
# -----------------------------
# [3 4 2 1 5]
# educationfield
# -----------------------------
# [nan 'Life Sciences' 'Technical Degree' 'Medical' 'Other' 'Marketing'
#  'Human Resources']
# jobrole
# -----------------------------
# [' resEArch DIREcToR ' ' ManAGeR ' ' ManaGER ' ... ' sAlES ExECUTivE '
#  ' SaLes ExecUtIVe ' ' mAnUfactURInG DiRECTOr ']
# maritalstatus
# -----------------------------
# [nan 'Married' 'Divorced' 'Single' 'divorced' 'Marreid']
# overtime
# -----------------------------
# ['No' nan 'Yes']
# performancerating
# -----------------------------
# ['3,0' '4,0' nan]
# standardhours
# -----------------------------
# ['Full Time' nan 'Part Time']
# totalworkingyears
# -----------------------------
# [nan '34,0' '22,0' '28,0' '20,0' '21,0' '33,0' '40,0' '18,0' '25,0' '15,0'
#  '17,0' '26,0' '16,0' '24,0' '14,0' '23,0' '27,0' '19,0' '11,0' '38,0'
#  '37,0' '13,0' '12,0' '29,0' '10,0' '36,0' '35,0' '9,0' '31,0' '32,0'
#  '8,0' '7,0' '30,0' '6,0' '5,0' '4,0' '3,0' '2,0' '1,0' '0,0']
# worklifebalance
# -----------------------------
# ['3,0' nan '2,0' '4,0' '1,0']
# salary
# -----------------------------
# ['195370,00$' '199990,00$' '192320,00$' '171690,00$' nan '100071,84$'
#  '53914,11$' '165950,00$' '199730,00$' '134020,00$' '132060,00$'
#  '195450,00$' '180410,00$' '192460,00$' '107480,00$' '167520,00$'
#  '62010,00$' '198450,00$' '40010,00$' '104470,00$' '191324,62$'
#  '160640,00$' '32100,00$' '102660,00$' '104750,00$' '61620,00$'
#  '47210,00$' '153407,07$' '28111,13$' '46150,00$' '169590,00$' '54060,00$'
#  '59020,00$' '108550,00$' '59140,00$' '66460,00$' '139730,00$' '66870,00$'
#  '47350,00$' '138720,00$' '190450,00$' '96130,00$' '115100,00$'
#  '170460,00$' '36920,00$' '198470,00$' '23080,00$' '57470,00$'
#  '104220,00$' '63470,00$' '23480,00$' '30720,00$' '124900,00$' '80200,00$'
#  '170680,00$' '89430,00$' '192720,00$' '55770,00$' '26910,00$' '74030,00$'
#  '88230,00$' '35790,00$' '177790,00$' '182130,00$' '135770,00$'
#  '191900,00$' '171230,00$' '191870,00$' '79880,00$' '70830,00$'
#  '34070,00$' '29290,00$' '120310,00$' '154270,00$' '51260,00$' '96190,00$'
#  '190330,00$' '104000,00$' '56740,00$' '191970,00$' '84120,00$'
#  '33480,00$' '53090,00$' '76540,00$' '128080,00$' '65860,00$' '25190,00$'
#  '170990,00$' '131200,00$' '44440,00$' '98520,00$' '178610,00$'
#  '137570,00$' '165980,00$' '42850,00$' '101240,00$' '97140,00$'
#  '99240,00$' '112450,00$' '92410,00$' '64720,00$' '30550,00$' '83210,00$'
#  '31430,00$' '85780,00$' '98880,00$' '133410,00$' '29090,00$' '95260,00$'
#  '44240,00$' '60740,00$' '61460,00$' '61720,00$' '46680,00$' '56050,00$'
#  '43190,00$' '35640,00$' '62610,00$' '68040,00$' '194360,00$' '24550,00$'
#  '50550,00$' '52570,00$' '59740,00$' '30340,00$' '83920,00$' '40510,00$'
#  '48050,00$' '53370,00$' '94340,00$' '53960,00$' '111590,00$' '87930,00$'
#  '191890,00$' '22160,00$' '117130,00$' '53040,00$' '111030,00$'
#  '66320,00$' '75870,00$' '43350,00$' '59800,00$' '52280,00$' '27000,00$'
#  '23660,00$' '23290,00$' '42940,00$' '67250,00$' '103250,00$' '44470,00$'
#  '108450,00$' '54720,00$' '63850,00$' '75250,00$' '87400,00$' '134990,00$'
#  '34910,00$' '102520,00$' '197400,00$' '62090,00$' '70940,00$' '45340,00$'
#  '85000,00$' '46390,00$' '53630,00$' '40810,00$' '35780,00$' '173280,00$'
#  '107930,00$' '108510,00$' '104660,00$' '23620,00$' '64390,00$'
#  '57690,00$' '40660,00$' '52060,00$' '25700,00$' '45020,00$' '49680,00$'
#  '51470,00$' '27180,00$' '54680,00$' '96670,00$' '51540,00$' '56750,00$'
#  '73140,00$' '50980,00$' '135700,00$' '67120,00$' '99910,00$' '102480,00$'
#  '25930,00$' '80950,00$' '168560,00$' '45370,00$' '179240,00$' '40140,00$'
#  '127420,00$' '33760,00$' '104820,00$' '42490,00$' '195860,00$'
#  '82370,00$' '47740,00$' '45680,00$' '59930,00$' '64990,00$' '34520,00$'
#  '63970,00$' '27250,00$' '36220,00$' '61800,00$' '62740,00$' '43810,00$'
#  '25590,00$' '54880,00$' '25140,00$' '31960,00$' '34200,00$' '53680,00$'
#  '129360,00$' '42210,00$' '49630,00$' '76390,00$' '135250,00$' '63800,00$'
#  '31020,00$' '45560,00$' '42300,00$' '48590,00$' '63220,00$' '107610,00$'
#  '29730,00$' '52040,00$' '173990,00$' '168850,00$' '43230,00$' '51550,00$'
#  '29360,00$' '187890,00$' '48830,00$' '20290,00$' '29960,00$' '92780,00$'
#  '88530,00$' '48760,00$' '21410,00$' '39360,00$' '68420,00$' '39890,00$'
#  '49300,00$' '27050,00$' '44480,00$' '23790,00$' '54870,00$' '28100,00$'
#  '89380,00$' '99360,00$' '54540,00$' '54730,00$' '135030,00$' '135490,00$'
#  '181720,00$' '27740,00$' '94390,00$' '52650,00$' '38150,00$' '23890,00$'
#  '175840,00$' '48690,00$' '46490,00$' '104960,00$' '27680,00$' '34080,00$'
#  '37550,00$' '21870,00$' '42580,00$' '53260,00$' '27820,00$' '176390,00$'
#  '60620,00$' '62880,00$' '34240,00$' '41940,00$' '25320,00$' '56660,00$'
#  '137260,00$' '41070,00$' '35970,00$' '41150,00$' '62720,00$' '25170,00$'
#  '39040,00$' '92040,00$' '43730,00$' '20640,00$' '24300,00$' '48770,00$'
#  '37600,00$' '29740,00$' '27660,00$' '33770,00$' '42130,00$' '65130,00$'
#  '42840,00$' '22260,00$' '55610,00$' '53730,00$' '28970,00$' '54100,00$'
#  '48500,00$' '39440,00$' '29600,00$' '189470,00$' '64650,00$' '26830,00$'
#  '20140,00$' '34410,00$' '136640,00$' '50210,00$' '188440,00$'
#  '106500,00$' '43170,00$' '20240,00$' '30580,00$' '39290,00$' '44250,00$'
#  '23280,00$' '59400,00$' '26220,00$' '32120,00$' '29110,00$' '69310,00$'
#  '21760,00$' '32300,00$' '186650,00$' '27890,00$' '64100,00$' '49410,00$'
#  '39830,00$' '29040,00$' '21740,00$' '26570,00$' '109650,00$' '25430,00$'
#  '194060,00$' '65380,00$' '22180,00$' '26540,00$' '119350,00$' '25460,00$'
#  '38940,00$' '42620,00$' '105270,00$' '36810,00$' '34470,00$' '88470,00$'
#  '20450,00$' '48510,00$' '81200,00$' '45770,00$' '54050,00$' '37080,00$'
#  '137700,00$' '24500,00$' '43420,00$' '31490,00$' '53240,00$' '43820,00$'
#  '25530,00$' '59330,00$' '44030,00$' '109340,00$' '20220,00$' '42560,00$'
#  '28990,00$' '23770,00$' '24040,00$' '27990,00$' '28110,00$' '43770,00$'
#  '42270,00$' '39170,00$' '49690,00$' '20420,00$' '22070,00$' '20700,00$'
#  '27910,00$' '82240,00$' '26100,00$' '57310,00$' '25390,00$' '23760,00$'
#  '190810,00$' '27430,00$' '45380,00$' '38670,00$' '20800,00$' '20960,00$'
#  '46270,00$' '23020,00$' '50710,00$' '54670,00$' '23940,00$' '36290,00$'
#  '93620,00$' '32290,00$' '164220,00$' '44000,00$' '20660,00$' '66510,00$'
#  '48980,00$' '31800,00$' '112440,00$' '63920,00$' '33120,00$' '31170,00$'
#  '152020,00$' '25800,00$' '21660,00$' '43740,00$' '55050,00$' '159720,00$'
#  '23050,00$' '34770,00$' '39070,00$' '34450,00$' '27600,00$' '62940,00$'
#  '21050,00$' '39020,00$' '20620,00$' '25870,00$' '55070,00$' '81030,00$'
#  '39780,00$' '53990,00$' '44400,00$' '26600,00$' '33750,00$' '22690,00$'
#  '47870,00$' '28090,00$' '25710,00$' '61420,00$' '24960,00$' '34190,00$'
#  '25010,00$' '39200,00$' '65400,00$' '161840,00$' '171590,00$' '36170,00$'
#  '26840,00$' '192370,00$' '44220,00$' '26780,00$' '51710,00$' '119160,00$'
#  '93800,00$' '24680,00$' '41270,00$' '21480,00$' '38860,00$' '20900,00$'
#  '20860,00$' '19510,00$' '30220,00$' '97240,00$' '33880,00$' '23220,00$'
#  '45050,00$' '28350,00$' '65530,00$' '66730,00$' '135910,00$' '21770,00$'
#  '195170,00$' '192020,00$' '100480,00$' '27230,00$' '66440,00$'
#  '31610,00$' '12000,00$' '52380,00$' '99850,00$' '159920,00$' '23700,00$'
#  '67810,00$' '28510,00$' '52580,00$' '22850,00$' '41970,00$' '45580,00$'
#  '17020,00$' '25640,00$' '50700,00$' '37800,00$' '98240,00$' '18780,00$'
#  '21270,00$' '20330,00$' '96020,00$' '166270,00$' '20830,00$' '10090,00$'
#  '78610,00$' '26420,00$' '51210,00$' '26940,00$' '50940,00$' '22740,00$'
#  '23140,00$' '23800,00$' '20080,00$' '105520,00$' '22590,00$' '24130,00$'
#  '21210,00$' '24790,00$' '131940,00$' '26000,00$' '183030,00$' '47770,00$'
#  '10520,00$' '24610,00$' '25960,00$' '47280,00$' '73510,00$' '47660,00$'
#  '22580,00$' '28270,00$' '28530,00$' '22900,00$' '21070,00$' '22100,00$'
#  '131910,00$' '182650,00$' '23720,00$' '28380,00$' '180610,00$'
#  '16110,00$' '47680,00$' '12740,00$' '25610,00$' '15630,00$' '83760,00$'
#  '48410,00$' '29720,00$' '68150,00$' '175670,00$' '15690,00$' '41870,00$'
#  '33060,00$' '13930,00$' '108830,00$' '67350,00$' '97560,00$' '52940,00$'
#  '24370,00$' '40710,00$' '29560,00$' '46480,00$' '28040,00$' '24390,00$'
#  '29330,00$' '10910,00$' '51510,00$' '28630,00$' '11290,00$' '194310,00$'
#  '21440,00$' '160150,00$' '43060,00$' '28210,00$' '35390,00$' '58130,00$'
#  '26960,00$' '67550,00$' '58280,00$' '132120,00$' '27410,00$' '49600,00$'
#  '42440,00$']
# roledepartament
# -----------------------------
# [nan ' ManaGER  -  Research & Development '
#  ' MANAger  -  Research & Development '
#  ' heaLtHcArE repResENtATiVe  -  Research & Development '
#  ' saLEs exEcutIVe  -  Sales ' ' Sales ExECuTIVe  -  Sales '
#  ' heALthCArE RePResEntaTIVe  -  Research & Development '
#  ' lABORAtOry tECHnIcIan  -  Research & Development '
#  ' ManufactUrINg DiReCTOr  -  Research & Development '
#  ' SaleS eXEcUtIVE  -  Sales '
#  ' HEaLthcaRe rEprEsEnTAtiVe  -  Research & Development '
#  ' rESeArCH sCientIST  -  Research & Development '
#  ' healTHCAre rePREseNtATiVE  -  Research & Development '
#  ' mANaGer  -  Research & Development '
#  ' HEAltHCaRe REPreseNTatIve  -  Research & Development '
#  ' SaLeS eXECUTivE  -  Sales '
#  ' reSeARCH SCIEnTiST  -  Research & Development '
#  ' ReSearch DiRecTOR  -  Research & Development '
#  ' resEaRCh SciEnTist  -  Research & Development '
#  ' hUmaN REsoUrCes  -  Human Resources '
#  ' manAgER  -  Research & Development ' ' SaLES eXeCUtIVE  -  Sales '
#  ' reSEarCH scIentISt  -  Research & Development '
#  ' ReSeARCh DiRECtor  -  Research & Development ' ' MaNAgeR  -  Sales '
#  ' RESEArCH sCIenTIst  -  Research & Development '
#  ' hUMAn reSoUrCES  -  Human Resources '
#  ' HUmAN rESOuRceS  -  Human Resources ' ' SaleS EXeCuTivE  -  Sales '
#  ' ReSeARch scIENTISt  -  Research & Development '
#  ' LaBoRaTorY TeChNicIAn  -  Research & Development '
#  ' ManUfaCTUriNg dIReCtor  -  Research & Development '
#  ' saLES ExECuTIVe  -  Sales '
#  ' RESEaRch SCIEntISt  -  Research & Development '
#  ' mAnUFaCtUrinG diReCtor  -  Research & Development '
#  ' maNUFAcTURING direCTOr  -  Research & Development '
#  ' labOraTORy techNicIan  -  Research & Development '
#  ' SAlEs ExeCUtive  -  Sales '
#  ' MANUFACturING DIRecToR  -  Research & Development '
#  ' Sales eXECuTIvE  -  Sales '
#  ' mANUfaCTuRiNG DiRECtOr  -  Research & Development '
#  ' ManUFACtURiNg DiRECTOr  -  Research & Development '
#  ' ResEARcH DiReCToR  -  Research & Development '
#  ' MANAgER  -  Research & Development '
#  ' labORATORY TechnIcIaN  -  Research & Development '
#  ' MaNUfacTurINg DiReCTor  -  Research & Development '
#  ' ReSEaRcH sciENTIST  -  Research & Development '
#  ' rESEARCh dIrEcTOr  -  Research & Development '
#  ' MANUfACTuRinG diRecTOR  -  Research & Development '
#  ' HeaLThCArE REpRESENTAtIVe  -  Research & Development '
#  ' LABOraTory TecHnIciaN  -  Research & Development '
#  ' sales rEprESEntAtIvE  -  Sales '
#  ' mANuFacTurinG DirECtoR  -  Research & Development '
#  ' lABorATOrY TeChnICIan  -  Research & Development '
#  ' RESEarCh SCIEnTiST  -  Research & Development '
#  ' SALes exEcuTIVe  -  Sales '
#  ' REseARCH DirectOr  -  Research & Development '
#  ' sAlES EXEcUtIVe  -  Sales '
#  ' lABoraToRY teCHnIcIaN  -  Research & Development '
#  ' LaBorATORy tEChnICiaN  -  Research & Development '
#  ' sales ExecutIvE  -  Sales ' ' sAles exECUtiVe  -  Sales '
#  ' SALEs eXecuTiVE  -  Sales ' ' SaleS executIVE  -  Sales '
#  ' rEsEArCH sCIeNTIST  -  Research & Development '
#  ' reSEArch SCIEntIsT  -  Research & Development '
#  ' rESeArCh DIrEctor  -  Research & Development '
#  ' saLES ExECUtiVe  -  Sales '
#  ' LaboRATory tEchNICIAn  -  Research & Development '
#  ' SAlEs exECUtIVe  -  Sales ' ' salEs eXECuTivE  -  Sales '
#  ' ReseaRch scIenTisT  -  Research & Development '
#  ' LaBoraTORY teCHNiCIaN  -  Research & Development '
#  ' sALEs ExeCuTive  -  Sales '
#  ' heALtHCARE rePResENtAtivE  -  Research & Development '
#  ' ManAgEr  -  Research & Development '
#  ' laboRAtORy TecHnICiAN  -  Research & Development '
#  ' ReSeARCH diRECtoR  -  Research & Development '
#  ' LAborAtOry TEchniCIAn  -  Research & Development '
#  ' SaLeS eXECutiVE  -  Sales ' ' SalEs eXECuTive  -  Sales '
#  ' rESeaRCH DIReCToR  -  Research & Development '
#  ' mANAGeR  -  Human Resources ' ' saLeS exECUtive  -  Sales '
#  ' maNuFAcTURInG DIReCtoR  -  Research & Development '
#  ' LABORaTorY TEChNIcIAN  -  Research & Development '
#  ' hEalTHcARe RePrEseNTATive  -  Research & Development '
#  ' mANuFActuring DireCtOR  -  Research & Development '
#  ' MaNagEr  -  Research & Development ' ' SaLeS exeCuTIVe  -  Sales '
#  ' lAboRaTory tECHNIciAN  -  Research & Development '
#  ' saLes eXECUTIVe  -  Sales ' ' saLes EXEcuTiVe  -  Sales '
#  ' mAnaGeR  -  Research & Development '
#  ' HEALThCaRe rePResEnTaTivE  -  Research & Development '
#  ' mAnAgEr  -  Research & Development '
#  ' MaNageR  -  Research & Development '
#  ' HeAlThCarE rEpreSentatiVe  -  Research & Development '
#  ' HUMAN ResoURCeS  -  Human Resources '
#  ' huMAn ResOurces  -  Human Resources '
#  ' mANUfacTURiNG dIRectOR  -  Research & Development '
#  ' saLES eXEcUTiVE  -  Sales '
#  ' labORaTORY teChNIcIaN  -  Research & Development '
#  ' saLes eXeCUTivE  -  Sales ' ' Sales exECutIVE  -  Sales '
#  ' saleS eXEcuTIvE  -  Sales ' ' SALes ExeCUtive  -  Sales '
#  ' reSearCH SCieNtIst  -  Research & Development '
#  ' HEALThcaRe RePresENtaTiVE  -  Research & Development '
#  ' rEsEARch sCientIST  -  Research & Development '
#  ' HealthcARE RePreSENtAtiVe  -  Research & Development '
#  ' ResEArch ScieNTiST  -  Research & Development '
#  ' labORaTORy TecHniciAN  -  Research & Development '
#  ' SalEs exECUTIvE  -  Sales '
#  ' LabOrATory TEChNICiaN  -  Research & Development '
#  ' reSeArcH scieNtist  -  Research & Development '
#  ' maNuFAcTUring DIrecToR  -  Research & Development '
#  ' ResEARCh DIRECtoR  -  Research & Development '
#  ' SaLes exECutIVe  -  Sales ' ' SAleS eXecuTIVe  -  Sales '
#  ' manAGER  -  Sales '
#  ' LaBOrATORy teCHnIciaN  -  Research & Development '
#  ' SAlES ExecuTIVe  -  Sales ' ' salES exEcUtiVE  -  Sales '
#  ' SAlEs ExECUTIVe  -  Sales '
#  ' HEaLTHcaRE rePReseNtaTIvE  -  Research & Development '
#  ' sAles eXEcUtIve  -  Sales '
#  ' laBoraTorY tEChnICiaN  -  Research & Development '
#  ' MANufacTURIng diREcTOr  -  Research & Development '
#  ' REsearch scIENtist  -  Research & Development '
#  ' heaLtHcARe RePReSENtaTIve  -  Research & Development '
#  ' lAbOrAtorY techNiCiaN  -  Research & Development '
#  ' laboRaTOrY TEchniCIaN  -  Research & Development '
#  ' SAles ExECutIvE  -  Sales '
#  ' HeALtHCarE represEntAtIVe  -  Research & Development '
#  ' HEalThCaRe rEpReSENtatIVe  -  Research & Development '
#  ' HEalTHCare REPrEsEntATiVE  -  Research & Development '
#  ' LaBoRaToRY TEcHnIcian  -  Research & Development '
#  ' SAlES ExecutIve  -  Sales '
#  ' LaBOrAtory TECHNIciAN  -  Research & Development '
#  ' ReSeArch scIenTIsT  -  Research & Development '
#  ' SaLEs EXECutIVe  -  Sales '
#  ' rESEARch DiRector  -  Research & Development '
#  ' HEaltHcare rEPrEsEnTatIVe  -  Research & Development '
#  ' lABORatORY TeChNiCiAN  -  Research & Development '
#  ' LaBOratory TeChnICiAn  -  Research & Development '
#  ' maNAGer  -  Sales ' ' hUMAn rEsOuRCES  -  Human Resources '
#  ' sales ExeCUTiVE  -  Sales ' ' saLEs exeCUtiVe  -  Sales '
#  ' laBorAtORy TECHnicIaN  -  Research & Development '
#  ' ReSeaRch SCIEnTiSt  -  Research & Development '
#  ' rEsEArcH scIenTIst  -  Research & Development '
#  ' RESeArch dIREcToR  -  Research & Development '
#  ' saLes ExECutIVE  -  Sales '
#  ' REseARCh SCIenTIst  -  Research & Development '
#  ' sALEs exECuTiVe  -  Sales '
#  ' rEseArCh SCieNtiST  -  Research & Development '
#  ' lABoRAtoRY TecHnIcian  -  Research & Development '
#  ' researcH SciEntIST  -  Research & Development '
#  ' REseARCH ScIeNTIST  -  Research & Development '
#  ' sAles ExecUtive  -  Sales '
#  ' mAnUfaCTuRing DiRecTor  -  Research & Development '
#  ' SaLes exEcUtIvE  -  Sales '
#  ' ReseArCH scIenTIst  -  Research & Development '
#  ' ReseArch sCienTiST  -  Research & Development '
#  ' ReSEarcH SCiEnTISt  -  Research & Development '
#  ' laBORATORY tECHNiciAN  -  Research & Development '
#  ' rESeArCH sCIeNtISt  -  Research & Development '
#  ' humAN resoURCEs  -  Human Resources '
#  ' REseARCh scieNTIsT  -  Research & Development '
#  ' SaLeS REPRESENtATIvE  -  Sales '
#  ' ResEArch SciEntiST  -  Research & Development '
#  ' ReSEaRCh SCIEnTist  -  Research & Development '
#  ' hUmAn REsOurCES  -  Human Resources ' ' sALeS EXecuTIVe  -  Sales '
#  ' ReseArCh SciENTIsT  -  Research & Development '
#  ' sALes rEprESentAtIvE  -  Sales '
#  ' humaN reSOUrcEs  -  Human Resources '
#  ' lAboRatOrY TechNiCiAn  -  Research & Development '
#  ' HeAlthcaRE rEPrEseNTaTIVE  -  Research & Development '
#  ' sALeS eXecuTIvE  -  Sales ' ' SALeS RepREsEnTatiVe  -  Sales '
#  ' SaLes rePrESENTaTivE  -  Sales '
#  ' rESEaRch sCientISt  -  Research & Development '
#  ' laBORatoRy TEcHnician  -  Research & Development '
#  ' ReSeaRch SCIentiST  -  Research & Development '
#  ' RESEarch ScieNtIst  -  Research & Development '
#  ' sALeS RePresenTAtivE  -  Sales '
#  ' LABORAToRy tEchNICiAn  -  Research & Development '
#  ' ResEArch sCIEnTiST  -  Research & Development '
#  ' ReSEArcH sCIeNtist  -  Research & Development '
#  ' LaBoRaTory techNICIAN  -  Research & Development '
#  ' hEaLThcARE rEpresEntATiVE  -  Research & Development '
#  ' mANufActuRIng DirECTOR  -  Research & Development '
#  ' laBOraTOrY TecHNIcIan  -  Research & Development '
#  ' sALES ReprEsentatiVE  -  Sales '
#  ' laBoRatoRy TEChNICiAN  -  Research & Development '
#  ' ReSEarch scIeNTIsT  -  Research & Development '
#  ' researCh SCientIsT  -  Research & Development '
#  ' ReseaRch scIENTisT  -  Research & Development '
#  ' lAboRaToRY teChNICIan  -  Research & Development '
#  ' rEsEaRCh diReCtOR  -  Research & Development '
#  ' labORAtoRy tEcHNICIAN  -  Research & Development '
#  ' SAlES exeCutive  -  Sales '
#  ' hEalthCaRe reprEseNTaTiVe  -  Research & Development '
#  ' ManufacTURInG DIRECtOR  -  Research & Development '
#  ' sAles exEcUtIve  -  Sales '
#  ' reseARCh SCieNTisT  -  Research & Development '
#  ' reSEarcH scIENtISt  -  Research & Development '
#  ' reseArCH scIentISt  -  Research & Development '
#  ' MANuFaCturiNG dIRECTOR  -  Research & Development '
#  ' HuMan resoUrCes  -  Human Resources '
#  ' huMAn Resources  -  Human Resources ' ' Sales EXEcUTiVe  -  Sales '
#  ' reSEaRCH scIenTisT  -  Research & Development '
#  ' sales rEpRESEnTatIve  -  Sales '
#  ' reseaRch DIrecTOr  -  Research & Development '
#  ' sALeS eXECutivE  -  Sales ' ' Human REsouRCeS  -  Human Resources '
#  ' rESeArcH sCientIST  -  Research & Development '
#  ' SAlES RepreSENtATiVe  -  Sales ' ' SAles execUTIve  -  Sales '
#  ' RESEArch SCIEnTISt  -  Research & Development '
#  ' labOrATOry TEchnIcIaN  -  Research & Development '
#  ' sALes ExEcUTIVe  -  Sales '
#  ' REsEARch sCIenTIsT  -  Research & Development '
#  ' RESeARch ScIeNtisT  -  Research & Development '
#  ' rEseARCH ScIeNtIST  -  Research & Development '
#  ' ManAGEr  -  Research & Development '
#  ' LaBoratory TECHnICIAn  -  Research & Development '
#  ' saLES exEcutivE  -  Sales '
#  ' LABorATory TecHnIcIaN  -  Research & Development '
#  ' HumAN REsourceS  -  Human Resources '
#  ' reseaRCh SCIentIst  -  Research & Development '
#  ' LaBOrAToRy teChNiciAn  -  Research & Development '
#  ' LaborAtorY Technician  -  Research & Development '
#  ' rEseaRCH sCIeNtiSt  -  Research & Development '
#  ' LABOrATOrY TEchnIcIAn  -  Research & Development '
#  ' ReSeARCh DireCtOr  -  Research & Development '
#  ' LaBORatORy tEchNiCian  -  Research & Development '
#  ' laBorATOrY TeChNIcIAn  -  Research & Development '
#  ' sALEs RePREsentaTive  -  Sales ' ' mAnageR  -  Sales '
#  ' rESEArcH SCiEntIst  -  Research & Development '
#  ' heAlThcaRe REprESeNTATive  -  Research & Development '
#  ' LABoratOry TeCHnIcIan  -  Research & Development '
#  ' hEAlthCarE rEpresenTATiVe  -  Research & Development '
#  ' HealTHcaRE rEPreSEntATive  -  Research & Development '
#  ' MaNUfActuRInG diREctOr  -  Research & Development '
#  ' saLes REPrEsentAtiVE  -  Sales '
#  ' LABorAtORy TEchnIciAn  -  Research & Development '
#  ' rEsEARcH ScieNTisT  -  Research & Development '
#  ' SalEs eXecuTive  -  Sales ' ' SaLeS EXEcUTiVe  -  Sales '
#  ' MaNufacTuRINg DirEcTor  -  Research & Development '
#  ' resEaRcH scIENTiSt  -  Research & Development '
#  ' SALes eXECuTIvE  -  Sales '
#  ' LabORatORy tEChnIcIAn  -  Research & Development '
#  ' LaBorAtOrY teCHNICIAn  -  Research & Development '
#  ' saLEs RePREsentAtiVE  -  Sales '
#  ' laBOrATORY TechNiCiAn  -  Research & Development '
#  ' sALes exECutIVe  -  Sales '
#  ' LabOraToRy technICiAN  -  Research & Development '
#  ' lAborAtORY TeCHNIciAN  -  Research & Development '
#  ' SAlES rePrESentaTIVe  -  Sales ' ' mANager  -  Research & Development '
#  ' HEAlThcARe rEPREseNtATIVe  -  Research & Development '
#  ' REsEArCH dIrECTOr  -  Research & Development '
#  ' rESeaRch SCIeNTIST  -  Research & Development '
#  ' SALEs REpRESentatIve  -  Sales ' ' SalES eXecUTiVE  -  Sales '
#  ' SaLes REPREseNtATive  -  Sales '
#  ' ReSeArch sCIEnTiSt  -  Research & Development '
#  ' sales REPReSeNtAtIVe  -  Sales ' ' sAles execUtIve  -  Sales '
#  ' LABOrATORy tEChNiCIaN  -  Research & Development '
#  ' hEalthCarE REPResEnTaTive  -  Research & Development '
#  ' mANagER  -  Research & Development ' ' sales repResENTaTiVE  -  Sales '
#  ' laboRAToRY tEChniCIAN  -  Research & Development '
#  ' resEaRcH sCIeNTisT  -  Research & Development '
#  ' maNuFAcTurING diREctOr  -  Research & Development '
#  ' mAnAger  -  Research & Development ' ' SALes eXEcUtiVe  -  Sales '
#  ' reSearCh SCiEnTist  -  Research & Development '
#  ' rESEARch SciENtiSt  -  Research & Development '
#  ' hUman ResourCeS  -  Human Resources ' ' SALES exeCUtIve  -  Sales '
#  ' ReseaRcH sCientiSt  -  Research & Development '
#  ' LAbORaTory tEcHnIciAN  -  Research & Development '
#  ' lABOraTOrY tecHniciaN  -  Research & Development '
#  ' sALeS exEcUtiVe  -  Sales ' ' salEs eXEcuTIvE  -  Sales '
#  ' SAleS ExEcuTiVE  -  Sales ' ' SaLeS exEcUTiVE  -  Sales '
#  ' ReSEArch scieNTiST  -  Research & Development '
#  ' reSEArCh sCieNtiST  -  Research & Development '
#  ' ReseaRCh dIRecTor  -  Research & Development '
#  ' SaLEs ExECUtiVE  -  Sales '
#  ' LAbORAToRy tEcHNICian  -  Research & Development '
#  ' sAleS EXECUtIvE  -  Sales ']
# remotework
# -----------------------------
# ['Yes' '1' 'False' '0' 'True']
#   age attrition businesstravel                department  distancefromhome  \
# 0  51        No            NaN                       NaN                 6
# 1  52        No            NaN                       NaN                 1
# 2  42        No  travel_rarely   Research & Development                  4
# 3  47        No  travel_rarely                       NaN                 2
# 4  46        No            NaN                       NaN                 3
#
#   education    educationfield  employeenumber  environmentsatisfaction  \
# 0         3               NaN               1                        1
# 1         4     Life Sciences               2                        3
# 2         2  Technical Degree               3                        3
# 3         4           Medical               4                        1
# 4         3  Technical Degree               5                        1
#
#    gender  jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0       0               3         5   resEArch DIREcToR                 3
# 1       0               2         5             ManAGeR                 3
# 2       0               3         5             ManaGER                 4
# 3       1               3         4   ReseArCH DIrECtOr                 3
# 4       1               4         4     sAleS EXECUtIve                 1
#
#   maritalstatus  numcompaniesworked overtime  percentsalaryhike  \
# 0           NaN                   7       No                 13
# 1           NaN                   0      NaN                 14
# 2       Married                   1       No                 11
# 3       Married                   3      NaN                 19
# 4      Divorced                   2       No                 12
#
#   performancerating  relationshipsatisfaction standardhours  stockoptionlevel  \
# 0               3,0                         3     Full Time                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2     Full Time                 2
# 4               3,0                         4           NaN                 1
#
#   totalworkingyears  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
#
#    yearssincelastpromotion  yearswithcurrmanager      salary  \
# 0                       15                    15  195370,00$
# 1                       11                     9  199990,00$
# 2                       11                    15  192320,00$
# 3                        5                     6  171690,00$
# 4                        2                     8         NaN
#
#                         roledepartament remotework
# 0                                   NaN        Yes
# 1                                   NaN          1
# 2   ManaGER  -  Research & Development           1
# 3                                   NaN      False
# 4                                   NaN          0

# %%
df.drop_duplicates(['employeenumber'], inplace = True)

# %%
df["employeenumber"].duplicated().sum()
# Out:
# np.int64(0)

# %%
limp.letras_a_numeros(df, 'age')
# Out:
# array([51, 52, 42, 47, 46, 48, 59, 41, 56, 38, 55, 40, 58, 35, 45, 33, 36,
#        34, 53, 43, 60, 32, 37, 49, 39, 50, 44, 30, 29, 31, 54, 57, 27, 28,
#        26, 25, 24, 23, 22, 21, 20, 19, 18])

# %%
divisas = ['salary']

for divi in divisas:
    limp.limpieza_divisas (df, divi, float)

# %%
numeros_limp = ['totalworkingyears', 'worklifebalance']

for num in numeros_limp:
    limp.limpieza_numeros(df, num, float)

# %%
limp.cambio_tipo(df, 'remotework', object)

# %%
limp.limpieza_boleanos (df, 'remotework', object)

# %%
df['remotework'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
limp.cambio_tipo(df, 'education', int)

# %%
limp.minusculas_titulos(df)

# %%
limp.minusculas(df)

# %%
limp.quitar_espacios(df)

# %%
limp.limpieza_genero (df, 'gender', str)

# %%
limp.limpieza_maritalstatus (df, 'maritalstatus')

# %%
cambio_a_objeto = ['relationshipsatisfaction', 'jobinvolvement', 'joblevel', 'jobsatisfaction', 'stockoptionlevel', 'worklifebalance', 'education', 'jobrole', 'environmentsatisfaction']
for col in cambio_a_objeto:
    limp.cambio_tipo(df, col, object)

# %%
enteros = ['worklifebalance']

for num_ent in enteros:
    limp.cambiar_a_entero(df, num_ent)

# %%
limp.primer_digito(df, 'environmentsatisfaction')

# %%
visual.extract_data(df)
# Out:
# INFORMACIÓN SOBRE COLUMNAS
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1614 non-null   int64
#  1   attrition                 1614 non-null   object
#  2   businesstravel            842 non-null    object
#  3   department                302 non-null    object
#  4   distancefromhome          1614 non-null   int64
#  5   education                 1614 non-null   object
#  6   educationfield            869 non-null    object
#  7   employeenumber            1614 non-null   int64
#  8   environmentsatisfaction   1614 non-null   object
#  9   gender                    1614 non-null   object
#  10  jobinvolvement            1614 non-null   object
#  11  joblevel                  1614 non-null   object
#  12  jobrole                   1614 non-null   object
#  13  jobsatisfaction           1614 non-null   object
#  14  maritalstatus             963 non-null    object
#  15  numcompaniesworked        1614 non-null   int64
#  16  overtime                  938 non-null    object
#  17  percentsalaryhike         1614 non-null   int64
#  18  performancerating         1419 non-null   object
#  19  relationshipsatisfaction  1614 non-null   object
#  20  standardhours             1276 non-null   object
#  21  stockoptionlevel          1614 non-null   object
#  22  totalworkingyears         1088 non-null   float64
#  23  trainingtimeslastyear     1614 non-null   int64
#  24  worklifebalance           1506 non-null   Int64
#  25  yearsatcompany            1614 non-null   int64
#  26  yearssincelastpromotion   1614 non-null   int64
#  27  yearswithcurrmanager      1614 non-null   int64
#  28  salary                    1340 non-null   float64
#  29  roledepartament           302 non-null    object
#  30  remotework                1614 non-null   object
# dtypes: Int64(1), float64(2), int64(9), object(19)
# memory usage: 405.1+ KB
# None
#
# --------------------------------------------------
#
# VISUALIZACIÓN DE NULOS
#
# age                            0
# attrition                      0
# businesstravel               772
# department                  1312
# distancefromhome               0
# education                      0
# educationfield               745
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                651
# numcompaniesworked             0
# overtime                     676
# percentsalaryhike              0
# performancerating            195
# relationshipsatisfaction       0
# standardhours                338
# stockoptionlevel               0
# totalworkingyears            526
# trainingtimeslastyear          0
# worklifebalance              108
# yearsatcompany                 0
# yearssincelastpromotion        0
# yearswithcurrmanager           0
# salary                       274
# roledepartament             1312
# remotework                     0
# dtype: int64
#
# VISUALIZACIÓN DE ÚNICOS
#
# attrition
# -----------------------------
# ['no' 'yes']
# businesstravel
# -----------------------------
# [nan 'travel_rarely' 'travel_frequently' 'non-travel']
# department
# -----------------------------
# [nan 'research & development' 'sales' 'human resources']
# education
# -----------------------------
# [3 4 2 1 5]
# educationfield
# -----------------------------
# [nan 'life sciences' 'technical degree' 'medical' 'other' 'marketing'
#  'human resources']
# environmentsatisfaction
# -----------------------------
# ['1' '3' '4' '2']
# gender
# -----------------------------
# ['Male' 'Female']
# jobinvolvement
# -----------------------------
# [3 2 4 1]
# joblevel
# -----------------------------
# [5 4 3 2 1]
# jobrole
# -----------------------------
# ['research director' 'manager' 'sales executive' 'manufacturing director'
#  'research scientist' 'healthcare representative' 'laboratory technician'
#  'sales representative' 'human resources']
# jobsatisfaction
# -----------------------------
# [3 4 1 2]
# maritalstatus
# -----------------------------
# [nan 'married' 'divorced' 'single']
# overtime
# -----------------------------
# ['no' nan 'yes']
# performancerating
# -----------------------------
# ['3,0' '4,0' nan]
# relationshipsatisfaction
# -----------------------------
# [3 1 4 2]
# standardhours
# -----------------------------
# ['full time' nan 'part time']
# stockoptionlevel
# -----------------------------
# [0 1 2 3]
# roledepartament
# -----------------------------
# [nan 'manager  -  research & development'
#  'healthcare representative  -  research & development'
#  'sales executive  -  sales'
#  'laboratory technician  -  research & development'
#  'manufacturing director  -  research & development'
#  'research scientist  -  research & development'
#  'research director  -  research & development'
#  'human resources  -  human resources' 'manager  -  sales'
#  'sales representative  -  sales' 'manager  -  human resources']
# remotework
# -----------------------------
# ['yes' 'no']
#    age attrition businesstravel              department  distancefromhome  \
# 0   51        no            NaN                     NaN                 6
# 1   52        no            NaN                     NaN                 1
# 2   42        no  travel_rarely  research & development                 4
# 3   47        no  travel_rarely                     NaN                 2
# 4   46        no            NaN                     NaN                 3
#
#   education    educationfield  employeenumber environmentsatisfaction  gender  \
# 0         3               NaN               1                       1    Male
# 1         4     life sciences               2                       3    Male
# 2         2  technical degree               3                       3    Male
# 3         4           medical               4                       1  Female
# 4         3  technical degree               5                       1  Female
#
#   jobinvolvement joblevel            jobrole jobsatisfaction maritalstatus  \
# 0              3        5  research director               3           NaN
# 1              2        5            manager               3           NaN
# 2              3        5            manager               4       married
# 3              3        4  research director               3       married
# 4              4        4    sales executive               1      divorced
#
#    numcompaniesworked overtime  percentsalaryhike performancerating  \
# 0                   7       no                 13               3,0
# 1                   0      NaN                 14               3,0
# 2                   1       no                 11               3,0
# 3                   3      NaN                 19               3,0
# 4                   2       no                 12               3,0
#
#   relationshipsatisfaction standardhours stockoptionlevel  totalworkingyears  \
# 0                        3     full time                0                NaN
# 1                        1           NaN                1               34.0
# 2                        4           NaN                0               22.0
# 3                        2     full time                2                NaN
# 4                        4           NaN                1                NaN
#
#    trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 0                      5                3              20
# 1                      5                3              33
# 2                      3             <NA>              22
# 3                      2             <NA>              20
# 4                      5                3              19
#
#    yearssincelastpromotion  yearswithcurrmanager    salary  \
# 0                       15                    15  195370.0
# 1                       11                     9  199990.0
# 2                       11                    15  192320.0
# 3                        5                     6  171690.0
# 4                        2                     8       NaN
#
#                       roledepartament remotework
# 0                                 NaN        yes
# 1                                 NaN        yes
# 2  manager  -  research & development        yes
# 3                                 NaN         no
# 4                                 NaN         no

# %% [markdown]
# # Gestión y Limpieza de Nulos

# %% [markdown]
# -Overtime: 41.477950
#
# -Marital Status: 40.22
#
# -standardhours: 20,91
#
# -worklifebalance (int64): 6,79
#
# -Businesstravel:
#
# -performancerating
#
# Vemos que todas las columnas categoricas las imputaremos por moda.

# %%
lista_moda = ['overtime', 'maritalstatus', 'standardhours', 'worklifebalance', 'businesstravel', 'performancerating']
for col in lista_moda:
    limp.objeto_moda(df, col)

# %%
nulos = df.isnull().sum()/df.shape[0]*100
# nulos ordenados de mayor a menor
nulos.sort_values(ascending=False)
# Out:
# department                  81.288724
# roledepartament             81.288724
# educationfield              46.158612
# totalworkingyears           32.589839
# salary                      16.976456
# businesstravel               0.000000
# age                          0.000000
# employeenumber               0.000000
# environmentsatisfaction      0.000000
# gender                       0.000000
# jobinvolvement               0.000000
# joblevel                     0.000000
# attrition                    0.000000
# distancefromhome             0.000000
# education                    0.000000
# maritalstatus                0.000000
# jobsatisfaction              0.000000
# jobrole                      0.000000
# numcompaniesworked           0.000000
# performancerating            0.000000
# relationshipsatisfaction     0.000000
# percentsalaryhike            0.000000
# overtime                     0.000000
# stockoptionlevel             0.000000
# standardhours                0.000000
# trainingtimeslastyear        0.000000
# worklifebalance              0.000000
# yearssincelastpromotion      0.000000
# yearsatcompany               0.000000
# yearswithcurrmanager         0.000000
# remotework                   0.000000
# dtype: float64

# %%
# Obtenemos la lista de columnas categóricas que tienen nulos
nulos_esta_cat = df[df.columns[df.isnull().any()]].select_dtypes(include = "O").columns
print("Las columnas categóricas que tienen nulos son : \n ")
print(nulos_esta_cat)
# Out:
# Las columnas categóricas que tienen nulos son :
#
# Index(['department', 'educationfield', 'roledepartament'], dtype='object')

# %%
# sacamos el 'value_counts()' de cada una de las columnas categóricas que tienen nulos para saber como es la distribución de sus categorías
for col in nulos_esta_cat:
    print(f"La distribución de las categorías para la columna {col.upper()}")
    display(df[col].value_counts() / df.shape[0]*100)  # display es una función utilizada para mostrar objetos de manera más legible en Jupyter Notebooks o entornos similares. 
    print("........................")
# Out:
# La distribución de las categorías para la columna DEPARTMENT
# department
# research & development    12.143742
# sales                      5.638166
# human resources            0.929368
# Name: count, dtype: float64
# ........................
# La distribución de las categorías para la columna EDUCATIONFIELD
# educationfield
# life sciences       21.623296
# medical             17.100372
# marketing            6.443618
# technical degree     4.275093
# other                3.655514
# human resources      0.743494
# Name: count, dtype: float64
# ........................
# La distribución de las categorías para la columna ROLEDEPARTAMENT
# roledepartament
# sales executive  -  sales                               4.275093
# research scientist  -  research & development           3.841388
# laboratory technician  -  research & development        3.469641
# healthcare representative  -  research & development    1.610905
# manufacturing director  -  research & development       1.363073
# sales representative  -  sales                          1.053284
# research director  -  research & development            0.991326
# manager  -  research & development                      0.867410
# human resources  -  human resources                     0.867410
# manager  -  sales                                       0.309789
# manager  -  human resources                             0.061958
# Name: count, dtype: float64
# ........................

# %% [markdown]
# Gestion de nulos de variables numericas:
#
# -totalworkingyears (int64): 32,71
#
# -distancefromhome: 12,04
#
# -Salary: 16.98

# %%
# para decidir si usamos la media o la mediana lo que haremos es hacer un describe de la columna para saber cuales son estos valores
df["worklifebalance"].describe()[["mean", "50%"]]
# Out:
# mean    2.775713
# 50%          3.0
# Name: worklifebalance, dtype: Float64

# %% [markdown]
# Vemos que la meadia es de 3 y la mediana de 2.7, ambas se parecen mucho, no distan demasiado la una de la otra. Podemos coger cualquiera de ellas para gestionar los nulos de "worklifebalance"

# %%
df.loc[df['distancefromhome'] < 0, 'distancefromhome'] = np.nan

# %%
dfh_negativo = df[df['distancefromhome'] < 0]
dfh_negativo
# Out:
# Empty DataFrame
# Columns: [age, attrition, businesstravel, department, distancefromhome, education, educationfield, employeenumber, environmentsatisfaction, gender, jobinvolvement, joblevel, jobrole, jobsatisfaction, maritalstatus, numcompaniesworked, overtime, percentsalaryhike, performancerating, relationshipsatisfaction, standardhours, stockoptionlevel, totalworkingyears, trainingtimeslastyear, worklifebalance, yearsatcompany, yearssincelastpromotion, yearswithcurrmanager, salary, roledepartament, remotework]
# Index: []

# %%
nulos = df.isnull().sum()/df.shape[0]*100

# nulos ordenados de mayor a menor
nulos.sort_values(ascending=False)
# Out:
# department                  81.288724
# roledepartament             81.288724
# educationfield              46.158612
# totalworkingyears           32.589839
# salary                      16.976456
# distancefromhome            11.895911
# businesstravel               0.000000
# employeenumber               0.000000
# environmentsatisfaction      0.000000
# gender                       0.000000
# jobinvolvement               0.000000
# joblevel                     0.000000
# attrition                    0.000000
# age                          0.000000
# education                    0.000000
# maritalstatus                0.000000
# jobsatisfaction              0.000000
# jobrole                      0.000000
# numcompaniesworked           0.000000
# performancerating            0.000000
# relationshipsatisfaction     0.000000
# percentsalaryhike            0.000000
# overtime                     0.000000
# stockoptionlevel             0.000000
# standardhours                0.000000
# trainingtimeslastyear        0.000000
# worklifebalance              0.000000
# yearssincelastpromotion      0.000000
# yearsatcompany               0.000000
# yearswithcurrmanager         0.000000
# remotework                   0.000000
# dtype: float64

# %%
imputer_iter = KNNImputer(n_neighbors=5)
df['distancefromhome'] = imputer_iter.fit_transform(df[['distancefromhome']])

# %%
imputer_iter = KNNImputer(n_neighbors=5)
df['salary'] = imputer_iter.fit_transform(df[['salary']])

# %%
imputer_iter = KNNImputer(n_neighbors=5)
df['totalworkingyears'] = imputer_iter.fit_transform(df[['totalworkingyears']])

# %%
nulos = df.isnull().sum()/df.shape[0]*100

# nulos ordenados de mayor a menor
nulos.sort_values(ascending=False)
# Out:
# department                  81.288724
# roledepartament             81.288724
# educationfield              46.158612
# businesstravel               0.000000
# attrition                    0.000000
# distancefromhome             0.000000
# age                          0.000000
# employeenumber               0.000000
# environmentsatisfaction      0.000000
# gender                       0.000000
# jobinvolvement               0.000000
# joblevel                     0.000000
# jobrole                      0.000000
# jobsatisfaction              0.000000
# education                    0.000000
# maritalstatus                0.000000
# numcompaniesworked           0.000000
# percentsalaryhike            0.000000
# overtime                     0.000000
# relationshipsatisfaction     0.000000
# standardhours                0.000000
# stockoptionlevel             0.000000
# performancerating            0.000000
# totalworkingyears            0.000000
# trainingtimeslastyear        0.000000
# yearsatcompany               0.000000
# worklifebalance              0.000000
# yearssincelastpromotion      0.000000
# yearswithcurrmanager         0.000000
# salary                       0.000000
# remotework                   0.000000
# dtype: float64

# %% [markdown]
# # VISUALIZACIÓN

# %%
# Matriz de correlación
num_vars = df.select_dtypes(include=np.number).columns.tolist()
correlation_matrix = df[num_vars].corr()

# %%
# Visualiza la matriz de correlación utilizando seaborn
plt.figure(figsize=(15, 8))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)

# Añade título
plt.title('Matriz de Correlación entre Variables')

# Muestra el gráfico

plt.show()

# %%
estadistica.grafico_pastel(df, 'attrition', 'Dimisiones')

# %%
sns.countplot(x='yearsatcompany', data=df, color = 'c', hue = 'attrition')

plt.xticks(rotation=45)

plt.xlabel("Años en la empresa")
plt.ylabel("Nº Empleados")

plt.show()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\4090720643.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:c'` for the same effect.
#
#   sns.countplot(x='yearsatcompany', data=df, color = 'c', hue = 'attrition')

# %%
grupo_veterania = df.groupby(['yearsatcompany', 'attrition'])['employeenumber'].count().reset_index()
grupo_veterania = grupo_veterania.rename(columns={'employeenumber': 'total'})
grupo_veterania
# Out:
#     yearsatcompany attrition  total
# 0                0        no     28
# 1                0       yes     16
# 2                1        no    112
# 3                1       yes     59
# 4                2        no    112
# ..             ...       ...    ...
# 59              33       yes      1
# 60              34        no      1
# 61              36        no      3
# 62              37        no      1
# 63              40       yes      2
#
# [64 rows x 3 columns]

# %%
def clasificar_veterania(df, col='yearsatcompany'):
    df['veterania'] = df[col].apply(lambda x: '+ de 10 años' if x > 10 else '-= de 10 años')
    return df

# %%
clasificar_veterania(df)
# Out:
#       age attrition businesstravel              department  distancefromhome  \
# 0      51        no  travel_rarely                     NaN          6.000000
# 1      52        no  travel_rarely                     NaN          1.000000
# 2      42        no  travel_rarely  research & development          4.000000
# 3      47        no  travel_rarely                     NaN          2.000000
# 4      46        no  travel_rarely                     NaN          3.000000
# ...   ...       ...            ...                     ...               ...
# 1609   36       yes  travel_rarely                     NaN          3.000000
# 1610   45        no     non-travel                     NaN          4.000000
# 1611   39        no  travel_rarely                     NaN          8.892405
# 1612   36        no     non-travel                     NaN          8.000000
# 1613   46        no  travel_rarely                     NaN          7.000000
#
#      education    educationfield  employeenumber environmentsatisfaction  \
# 0            3               NaN               1                       1
# 1            4     life sciences               2                       3
# 2            2  technical degree               3                       3
# 3            4           medical               4                       1
# 4            3  technical degree               5                       1
# ...        ...               ...             ...                     ...
# 1609         1     life sciences            1610                       3
# 1610         2               NaN            1611                       3
# 1611         5               NaN            1612                       1
# 1612         4  technical degree            1613                       1
# 1613         2           medical            1614                       4
#
#       gender jobinvolvement joblevel                 jobrole jobsatisfaction  \
# 0       Male              3        5       research director               3
# 1       Male              2        5                 manager               3
# 2       Male              3        5                 manager               4
# 3     Female              3        4       research director               3
# 4     Female              4        4         sales executive               1
# ...      ...            ...      ...                     ...             ...
# 1609    Male              2        3         sales executive               4
# 1610    Male              3        2   laboratory technician               2
# 1611    Male              4        3         sales executive               3
# 1612    Male              3        2         sales executive               4
# 1613    Male              3        3  manufacturing director               3
#
#      maritalstatus  numcompaniesworked overtime  percentsalaryhike  \
# 0          married                   7       no                 13
# 1          married                   0       no                 14
# 2          married                   1       no                 11
# 3          married                   3       no                 19
# 4         divorced                   2       no                 12
# ...            ...                 ...      ...                ...
# 1609       married                   1       no                 11
# 1610       married                   1       no                 12
# 1611        single                   0       no                 18
# 1612      divorced                   4       no                 13
# 1613       married                   6       no                 13
#
#      performancerating relationshipsatisfaction standardhours  \
# 0                  3,0                        3     full time
# 1                  3,0                        1     part time
# 2                  3,0                        4     part time
# 3                  3,0                        2     full time
# 4                  3,0                        4     part time
# ...                ...                      ...           ...
# 1609               3,0                        1     full time
# 1610               3,0                        2     part time
# 1611               3,0                        4     part time
# 1612               3,0                        4     part time
# 1613               3,0                        2     full time
#
#      stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                   0          11.318934                      5
# 1                   1          34.000000                      5
# 2                   0          22.000000                      3
# 3                   2          11.318934                      2
# 4                   1          11.318934                      5
# ...               ...                ...                    ...
# 1609                1          11.318934                      6
# 1610                0          11.318934                      5
# 1611                0           9.000000                      3
# 1612                2          12.000000                      3
# 1613                1          11.318934                      3
#
#       worklifebalance  yearsatcompany  yearssincelastpromotion  \
# 0                   3              20                       15
# 1                   3              33                       11
# 2                   3              22                       11
# 3                   3              20                        5
# 4                   3              19                        2
# ...               ...             ...                      ...
# 1609                3              16                        3
# 1610                2               9                        0
# 1611                3               8                        0
# 1612                3               7                        0
# 1613                3               8                        0
#
#       yearswithcurrmanager         salary                     roledepartament  \
# 0                       15  195370.000000                                 NaN
# 1                        9  199990.000000                                 NaN
# 2                       15  192320.000000  manager  -  research & development
# 3                        6  171690.000000                                 NaN
# 4                        8   65245.875313                                 NaN
# ...                    ...            ...                                 ...
# 1609                     7  103250.000000                                 NaN
# 1610                     8   44470.000000                                 NaN
# 1611                     7  100071.840000                                 NaN
# 1612                     7   53914.110000                                 NaN
# 1613                     7  108450.000000                                 NaN
#
#      remotework      veterania
# 0           yes   + de 10 años
# 1           yes   + de 10 años
# 2           yes   + de 10 años
# 3            no   + de 10 años
# 4            no   + de 10 años
# ...         ...            ...
# 1609         no   + de 10 años
# 1610        yes  -= de 10 años
# 1611        yes  -= de 10 años
# 1612         no  -= de 10 años
# 1613         no  -= de 10 años
#
# [1614 rows x 32 columns]

# %%
grafico = sns.countplot(x='veterania', data= df, color = 'c', hue = 'attrition')

plt.xticks(rotation=45)

plt.xlabel("Veteranía")
plt.ylabel("Total Empleados")

total = len(df)
for p in grafico.patches:
    height = p.get_height()
    percentage = f'{100 * height / total:.1f}%'
    grafico.text(
        p.get_x() + p.get_width() / 2, 
        height + 1,  # Ajuste para que no tape la barra
        percentage, 
        ha='center'
    )

plt.title("Distribución de empleados por veteranía y dimisiones")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\3765960839.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:c'` for the same effect.
#
#   grafico = sns.countplot(x='veterania', data= df, color = 'c', hue = 'attrition')

# %%
estadistica.grafico_pastel(df, 'gender', 'Género')

# %%
sns.countplot(x='gender', data=df, color = 'c', hue = 'attrition')

plt.xticks(rotation=45)

plt.xlabel("Género")
plt.ylabel("Total Empleados")

plt.show()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\1459566419.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:c'` for the same effect.
#
#   sns.countplot(x='gender', data=df, color = 'c', hue = 'attrition')

# %%
estadistica.grafico_pastel(df, 'standardhours', 'Distribución de la plantilla en función del tipo de jornada')

# %%
estadistica.grafico_pastel(df, 'remotework', 'Distribución de la plantilla en función del trabajo remoto')

# %%
estadistica.grafico_pastel(df, 'businesstravel', 'Distribución de la plantilla en función de los viajes')

# %%
df_ylp_s = df.groupby("jobsatisfaction").agg({
    "employeenumber": "nunique",
    "yearssincelastpromotion": "mean"}).reset_index()
df_ylp_s
# Out:
#    jobsatisfaction  employeenumber  yearssincelastpromotion
# 0                1             317                 2.381703
# 1                2             302                 2.274834
# 2                3             481                 2.147609
# 3                4             514                 2.237354

# %%
condicion_2 = df["jobsatisfaction"]>=3
df_condicion_2 = df[condicion_2]
df_condicion_2
# Out:
#       age attrition businesstravel              department  distancefromhome  \
# 0      51        no  travel_rarely                     NaN          6.000000
# 1      52        no  travel_rarely                     NaN          1.000000
# 2      42        no  travel_rarely  research & development          4.000000
# 3      47        no  travel_rarely                     NaN          2.000000
# 5      48        no  travel_rarely  research & development         22.000000
# ...   ...       ...            ...                     ...               ...
# 1607   31        no  travel_rarely                     NaN         12.000000
# 1609   36       yes  travel_rarely                     NaN          3.000000
# 1611   39        no  travel_rarely                     NaN          8.892405
# 1612   36        no     non-travel                     NaN          8.000000
# 1613   46        no  travel_rarely                     NaN          7.000000
#
#      education    educationfield  employeenumber environmentsatisfaction  \
# 0            3               NaN               1                       1
# 1            4     life sciences               2                       3
# 2            2  technical degree               3                       3
# 3            4           medical               4                       1
# 5            3           medical               6                       4
# ...        ...               ...             ...                     ...
# 1607         3           medical            1608                       4
# 1609         1     life sciences            1610                       3
# 1611         5               NaN            1612                       1
# 1612         4  technical degree            1613                       1
# 1613         2           medical            1614                       4
#
#       gender jobinvolvement joblevel                    jobrole  \
# 0       Male              3        5          research director
# 1       Male              2        5                    manager
# 2       Male              3        5                    manager
# 3     Female              3        4          research director
# 5     Female              3        4                    manager
# ...      ...            ...      ...                        ...
# 1607  Female              3        2  healthcare representative
# 1609    Male              2        3            sales executive
# 1611    Male              4        3            sales executive
# 1612    Male              3        2            sales executive
# 1613    Male              3        3     manufacturing director
#
#      jobsatisfaction maritalstatus  numcompaniesworked overtime  \
# 0                  3       married                   7       no
# 1                  3       married                   0       no
# 2                  4       married                   1       no
# 3                  3       married                   3       no
# 5                  4       married                   3       no
# ...              ...           ...                 ...      ...
# 1607               4       married                   0       no
# 1609               4       married                   1       no
# 1611               3        single                   0       no
# 1612               4      divorced                   4       no
# 1613               3       married                   6       no
#
#       percentsalaryhike performancerating relationshipsatisfaction  \
# 0                    13               3,0                        3
# 1                    14               3,0                        1
# 2                    11               3,0                        4
# 3                    19               3,0                        2
# 5                    11               3,0                        2
# ...                 ...               ...                      ...
# 1607                 11               3,0                        3
# 1609                 11               3,0                        1
# 1611                 18               3,0                        4
# 1612                 13               3,0                        4
# 1613                 13               3,0                        2
#
#      standardhours stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0        full time                0          11.318934                      5
# 1        part time                1          34.000000                      5
# 2        part time                0          22.000000                      3
# 3        full time                2          11.318934                      2
# 5        part time                1          11.318934                      3
# ...            ...              ...                ...                    ...
# 1607     part time                2          10.000000                      2
# 1609     full time                1          11.318934                      6
# 1611     part time                0           9.000000                      3
# 1612     part time                2          12.000000                      3
# 1613     full time                1          11.318934                      3
#
#       worklifebalance  yearsatcompany  yearssincelastpromotion  \
# 0                   3              20                       15
# 1                   3              33                       11
# 2                   3              22                       11
# 3                   3              20                        5
# 5                   3              22                        4
# ...               ...             ...                      ...
# 1607                1               9                        8
# 1609                3              16                        3
# 1611                3               8                        0
# 1612                3               7                        0
# 1613                3               8                        0
#
#       yearswithcurrmanager         salary                     roledepartament  \
# 0                       15  195370.000000                                 NaN
# 1                        9  199990.000000                                 NaN
# 2                       15  192320.000000  manager  -  research & development
# 3                        6  171690.000000                                 NaN
# 5                        7   65245.875313  manager  -  research & development
# ...                    ...            ...                                 ...
# 1607                     5   53914.110000                                 NaN
# 1609                     7  103250.000000                                 NaN
# 1611                     7  100071.840000                                 NaN
# 1612                     7   53914.110000                                 NaN
# 1613                     7  108450.000000                                 NaN
#
#      remotework      veterania
# 0           yes   + de 10 años
# 1           yes   + de 10 años
# 2           yes   + de 10 años
# 3            no   + de 10 años
# 5           yes   + de 10 años
# ...         ...            ...
# 1607         no  -= de 10 años
# 1609         no   + de 10 años
# 1611        yes  -= de 10 años
# 1612         no  -= de 10 años
# 1613         no  -= de 10 años
#
# [995 rows x 32 columns]

# %%
condicion_3 = df["jobsatisfaction"]<=2
df_condicion_3 = df[condicion_2]
df_condicion_3
# Out:
#       age attrition businesstravel              department  distancefromhome  \
# 0      51        no  travel_rarely                     NaN          6.000000
# 1      52        no  travel_rarely                     NaN          1.000000
# 2      42        no  travel_rarely  research & development          4.000000
# 3      47        no  travel_rarely                     NaN          2.000000
# 5      48        no  travel_rarely  research & development         22.000000
# ...   ...       ...            ...                     ...               ...
# 1607   31        no  travel_rarely                     NaN         12.000000
# 1609   36       yes  travel_rarely                     NaN          3.000000
# 1611   39        no  travel_rarely                     NaN          8.892405
# 1612   36        no     non-travel                     NaN          8.000000
# 1613   46        no  travel_rarely                     NaN          7.000000
#
#      education    educationfield  employeenumber environmentsatisfaction  \
# 0            3               NaN               1                       1
# 1            4     life sciences               2                       3
# 2            2  technical degree               3                       3
# 3            4           medical               4                       1
# 5            3           medical               6                       4
# ...        ...               ...             ...                     ...
# 1607         3           medical            1608                       4
# 1609         1     life sciences            1610                       3
# 1611         5               NaN            1612                       1
# 1612         4  technical degree            1613                       1
# 1613         2           medical            1614                       4
#
#       gender jobinvolvement joblevel                    jobrole  \
# 0       Male              3        5          research director
# 1       Male              2        5                    manager
# 2       Male              3        5                    manager
# 3     Female              3        4          research director
# 5     Female              3        4                    manager
# ...      ...            ...      ...                        ...
# 1607  Female              3        2  healthcare representative
# 1609    Male              2        3            sales executive
# 1611    Male              4        3            sales executive
# 1612    Male              3        2            sales executive
# 1613    Male              3        3     manufacturing director
#
#      jobsatisfaction maritalstatus  numcompaniesworked overtime  \
# 0                  3       married                   7       no
# 1                  3       married                   0       no
# 2                  4       married                   1       no
# 3                  3       married                   3       no
# 5                  4       married                   3       no
# ...              ...           ...                 ...      ...
# 1607               4       married                   0       no
# 1609               4       married                   1       no
# 1611               3        single                   0       no
# 1612               4      divorced                   4       no
# 1613               3       married                   6       no
#
#       percentsalaryhike performancerating relationshipsatisfaction  \
# 0                    13               3,0                        3
# 1                    14               3,0                        1
# 2                    11               3,0                        4
# 3                    19               3,0                        2
# 5                    11               3,0                        2
# ...                 ...               ...                      ...
# 1607                 11               3,0                        3
# 1609                 11               3,0                        1
# 1611                 18               3,0                        4
# 1612                 13               3,0                        4
# 1613                 13               3,0                        2
#
#      standardhours stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0        full time                0          11.318934                      5
# 1        part time                1          34.000000                      5
# 2        part time                0          22.000000                      3
# 3        full time                2          11.318934                      2
# 5        part time                1          11.318934                      3
# ...            ...              ...                ...                    ...
# 1607     part time                2          10.000000                      2
# 1609     full time                1          11.318934                      6
# 1611     part time                0           9.000000                      3
# 1612     part time                2          12.000000                      3
# 1613     full time                1          11.318934                      3
#
#       worklifebalance  yearsatcompany  yearssincelastpromotion  \
# 0                   3              20                       15
# 1                   3              33                       11
# 2                   3              22                       11
# 3                   3              20                        5
# 5                   3              22                        4
# ...               ...             ...                      ...
# 1607                1               9                        8
# 1609                3              16                        3
# 1611                3               8                        0
# 1612                3               7                        0
# 1613                3               8                        0
#
#       yearswithcurrmanager         salary                     roledepartament  \
# 0                       15  195370.000000                                 NaN
# 1                        9  199990.000000                                 NaN
# 2                       15  192320.000000  manager  -  research & development
# 3                        6  171690.000000                                 NaN
# 5                        7   65245.875313  manager  -  research & development
# ...                    ...            ...                                 ...
# 1607                     5   53914.110000                                 NaN
# 1609                     7  103250.000000                                 NaN
# 1611                     7  100071.840000                                 NaN
# 1612                     7   53914.110000                                 NaN
# 1613                     7  108450.000000                                 NaN
#
#      remotework      veterania
# 0           yes   + de 10 años
# 1           yes   + de 10 años
# 2           yes   + de 10 años
# 3            no   + de 10 años
# 5           yes   + de 10 años
# ...         ...            ...
# 1607         no  -= de 10 años
# 1609         no   + de 10 años
# 1611        yes  -= de 10 años
# 1612         no  -= de 10 años
# 1613         no  -= de 10 años
#
# [995 rows x 32 columns]

# %%
estadistica.grafico_pastel(df_condicion_2, 'joblevel', 'Distribución de la plantilla satisfecha por nivel del puesto de trabajo')

# %%
estadistica.grafico_pastel(df, 'jobsatisfaction', 'Distribución de la plantilla por nivel de satisfacción')

# %%
sns.countplot(x='joblevel', data=df, color = 'c', hue = 'jobsatisfaction')

plt.xticks(rotation=45)

plt.xlabel("Nivel del puesto de trabajo")
plt.ylabel("Total Empleados/as")

plt.show()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\30620506.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:c'` for the same effect.
#
#   sns.countplot(x='joblevel', data=df, color = 'c', hue = 'jobsatisfaction')

# %%
sns.countplot(x='businesstravel', data=df, color = 'c', hue = 'jobsatisfaction')

plt.xticks(rotation=45)

plt.xlabel("Frecuencia de viajes")
plt.ylabel("Total Empleados/as")

plt.show()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\590234680.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:c'` for the same effect.
#
#   sns.countplot(x='businesstravel', data=df, color = 'c', hue = 'jobsatisfaction')

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='jobrole', data=df, color = 'c', hue = 'jobsatisfaction')

plt.xticks(rotation=45)

plt.xlabel("Rol del puesto de trabajo")
plt.ylabel("Total Empleados/as")

plt.show()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\2129591323.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:c'` for the same effect.
#
#   sns.countplot(x='jobrole', data=df, color = 'c', hue = 'jobsatisfaction')

# %%
orden_environmentsatisfaction = ["1", "2", "3", "4"]
plt.figure(figsize=(10, 5)) 
sns.barplot(x = "environmentsatisfaction", 
            y = "employeenumber", 
            data = df,
            ci = None,
            palette = "coolwarm",
            order = orden_environmentsatisfaction)
plt.suptitle("Distribución de las personas trabajadoras en función de su satisfacción con el ambiente laboral ")
plt.tight_layout()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\2381785084.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = "environmentsatisfaction",
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\2381785084.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "environmentsatisfaction",

# %%
orden_jobinvolvement = ["1", "2", "3", "4"]
plt.figure(figsize=(10, 5)) 
sns.barplot(x = "jobinvolvement", 
            y = "employeenumber", 
            data = df,
            ci = None,
            palette = "coolwarm",
            order = orden_jobinvolvement)
plt.suptitle("Distribución de las personas trabajadoras en función de su compromiso en el trabajo")
plt.tight_layout()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\2480402296.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = "jobinvolvement",
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\2480402296.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "jobinvolvement",

# %%
orden_jobsatisfaction = ["1", "2", "3", "4"]
plt.figure(figsize=(10, 5)) 
sns.barplot(x = "jobsatisfaction", 
            y = "employeenumber", 
            data = df,
            ci = None,
            palette = "coolwarm",
            order = orden_jobinvolvement)
plt.suptitle("Distribución de las personas trabajadoras en función de su satisfacción en el puesto")
plt.tight_layout()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\2263532974.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = "jobsatisfaction",
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\2263532974.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "jobsatisfaction",

# %%
orden_jobsatisfaction = ["1", "2", "3", "4"]
plt.figure(figsize=(10, 5)) 
sns.barplot(x = "relationshipsatisfaction", 
            y = "employeenumber", 
            data = df,
            ci = None,
            palette = "coolwarm",
            order = orden_jobinvolvement)
plt.suptitle("Distribución de las personas trabajadoras en función de su satisfacción con las relaciones interpersonales en el trabajo")
plt.tight_layout()
# Out:
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\1368542486.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = "relationshipsatisfaction",
# C:\Users\Lidia\AppData\Local\Temp\ipykernel_11020\1368542486.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "relationshipsatisfaction",

# %%
df_sal_satis = df.groupby("environmentsatisfaction").agg({
    "salary": "mean"}).reset_index()
df_sal_satis
# Out:
#   environmentsatisfaction        salary
# 0                       1  65724.068581
# 1                       2  63814.019493
# 2                       3  64601.173308
# 3                       4  66491.810907

# %%
df_sal_satis_2 = df.groupby("jobinvolvement").agg({
    "salary": "mean"}).reset_index()
df_sal_satis_2
# Out:
#    jobinvolvement        salary
# 0               1  64171.338094
# 1               2  65916.339922
# 2               3  65735.998767
# 3               4  61315.127045

# %%
df_sal_satis_3 = df.groupby("jobsatisfaction").agg({
    "salary": "mean"}).reset_index()
df_sal_satis_3
# Out:
#    jobsatisfaction        salary
# 0                1  65772.596856
# 1                2  63516.186997
# 2                3  66373.486232
# 3                4  64882.089886

# %%
df_sal_satis_4 = df.groupby("relationshipsatisfaction").agg({
    "salary": "mean"}).reset_index()
df_sal_satis_4
# Out:
#    relationshipsatisfaction        salary
# 0                         1  61744.019304
# 1                         2  65866.555174
# 2                         3  66341.484052
# 3                         4  65883.621240

# %% [markdown]
# A través de estas tablas, podemos concluír que la variable salario no parece tener un impacto directo en la satisfacción del personal.

# %% [markdown]
# # BASE DE DATOS

# %%
# Conectar a MySQL usando pymysql
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='AlumnaAdalab',
    database='bd_talento_abc_company'
)
# Crear un cursor
cursor = connection.cursor()
# Crear una base de datos
cursor.execute("CREATE DATABASE IF NOT EXISTS bd_talento_ABC_Company")
print("Base de Datos creada exitosamente.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[61], line 2
#       1 # Conectar a MySQL usando pymysql
# ----> 2 connection = pymysql.connect(
#       3     host='localhost',
#       4     user='root',
#       5     password='AlumnaAdalab',
#       6     database='bd_talento_abc_company'
#       7 )
#       8 # Crear un cursor
#       9 cursor = connection.cursor()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359     self._sock = None
#     360 else:
# --> 361     self.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\connections.py:669, in Connection.connect(self, sock)
#     666 self._next_seq_id = 0
#     668 self._get_server_information()
# --> 669 self._request_authentication()
#     671 # Send "SET NAMES" query on init for:
#     672 # - Ensure charaset (and collation) is set to the server.
#     673 #   - collation_id in handshake packet may be ignored.
#    (...)
#     682 # - https://github.com/wagtail/wagtail/issues/9477
#     683 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     684 self.set_character_set(self.charset, self.collation)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\connections.py:979, in Connection._request_authentication(self)
#     977 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     978 if self._auth_plugin_name == "caching_sha2_password":
# --> 979     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     980 elif self._auth_plugin_name == "sha256_password":
#     981     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\_auth.py:268, in caching_sha2_password_auth(conn, pkt)
#     265         print(conn.server_public_key.decode("ascii"))
#     267 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 268 pkt = _roundtrip(conn, data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\_auth.py:121, in _roundtrip(conn, send_data)
#     119 def _roundtrip(conn, send_data):
#     120     conn.write_packet(send_data)
# --> 121     pkt = conn._read_packet()
#     122     pkt.check_error()
#     123     return pkt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'bd_talento_abc_company'")

# %%
df.to_csv('tabla_general.csv', index=False)

# %%
# Cargar el archivo CSV
df = pd.read_csv("tabla_general.csv")

# %%
# Conexión a la base de datos MySQL
engine = create_engine('mysql+pymysql://root:AlumnaAdalab@localhost/bd_talento_ABC_Company')

# %%
# Borrar datos previos en todas las tablas (en orden para evitar errores de relaciones)
with engine.begin() as conn:
    tablas = [
        "employee_info", "employee_career", "employee_rating", "employee_training",
        "employee_satisfaction", "employee_salary", "employee_conditions", "employee_company",
        "attrition"
    ]
    for tabla in tablas:
        conn.execute(text(f"DELETE FROM {tabla}"))
    print("Datos borrados de las tablas.")
# Out:
# Datos borrados de las tablas.

# %%
tablas_sql = {
    "employee_info": """
        CREATE TABLE IF NOT EXISTS employee_info (
            id_employee INT PRIMARY KEY,
            age INT,
            gender VARCHAR(100),
            maritalstatus VARCHAR(100),
            education VARCHAR(100),
            distancefromhome FLOAT
        )
    """,
    "employee_career": """
        CREATE TABLE IF NOT EXISTS employee_career (
            id_employee INT PRIMARY KEY,
            numcompaniesworked  INT,
            totalworkingyears FLOAT
        )
    """,
    "employee_rating": """
        CREATE TABLE IF NOT EXISTS employee_rating (
            id_employee INT PRIMARY KEY,
            jobinvolvement  VARCHAR(100),
            performancerating VARCHAR(100)
        )
    """,

       "employee_training": """
        CREATE TABLE IF NOT EXISTS employee_training (
            id_employee INT PRIMARY KEY,
            trainingtimeslastyear INT
        )
    """,

       "employee_satisfaction": """
        CREATE TABLE IF NOT EXISTS employee_satisfaction (
            id_employee INT PRIMARY KEY,
            environmentsatisfaction VARCHAR(100),
            jobsatisfaction VARCHAR(100),
            relationshipsatisfaction VARCHAR(100),
            worklifebalance VARCHAR(100)
        )
    """,
        "employee_salary": """
        CREATE TABLE IF NOT EXISTS employee_salary (
            id_employee INT PRIMARY KEY,
            salary FLOAT,
            percentsalaryhike INT
        )
    """,
        "employee_conditions": """
        CREATE TABLE IF NOT EXISTS employee_conditions (
            id_employee INT PRIMARY KEY,
            businesstravel VARCHAR(100),
            stockoptionlevel INT,
            standardhours VARCHAR(100),
            overtime VARCHAR(100), 
            remotework VARCHAR(100)
        )
    """,

        "employee_company": """
        CREATE TABLE IF NOT EXISTS employee_company (
            id_employee INT PRIMARY KEY,
            department VARCHAR(500),
            roledepartament VARCHAR(500),
            joblevel INT,
            jobrole VARCHAR(500), 
            yearsatcompany INT, 
            yearssincelastpromotion INT,
            yearswithcurrmanager INT
        )
    """,

        "attrition": """
        CREATE TABLE IF NOT EXISTS attrition (
            id_employee INT PRIMARY KEY,
            attrition VARCHAR(100)
        )
    """,

    
}

for tabla, sql in tablas_sql.items():
    with engine.begin() as conn:
        conn.execute(text(sql))
        print(f"Tabla {tabla} creada exitosamente.")
# Out:
# Tabla employee_info creada exitosamente.
# Tabla employee_career creada exitosamente.
# Tabla employee_rating creada exitosamente.
# Tabla employee_training creada exitosamente.
# Tabla employee_satisfaction creada exitosamente.
# Tabla employee_salary creada exitosamente.
# Tabla employee_conditions creada exitosamente.
# Tabla employee_company creada exitosamente.
# Tabla attrition creada exitosamente.

# %%
connection.commit()
cursor.close()
connection.close()

# %% [markdown]
# ## Insertar datos en las tablas de la base de datos

# %%
# Tabla de employee_info:
df_employee_info = df[['employeenumber', 'age', 'gender', 'maritalstatus', 'education', 'distancefromhome']]
df_employee_info.columns = ['id_employee', 'age', 'gender', 'maritalstatus', 'education', 'distancefromhome']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_info.empty:
    df_employee_info.to_sql('employee_info', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_info)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'artists'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'artists'

# %%
# Tabla de employee_career:
df_employee_career = df[['employeenumber', 'numcompaniesworked', 'totalworkingyears']]
df_employee_career.columns = ['id_employee', 'numcompaniesworked', 'totalworkingyears']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_career.empty:
    df_employee_career.to_sql('employee_career', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_career)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'df_employee_career'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'df_employee_career'

# %%
# Tabla de employee_rating:
df_employee_rating = df[['employeenumber', 'jobinvolvement', 'performancerating']]
df_employee_rating.columns = ['id_employee', 'jobinvolvement', 'performancerating']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_rating.empty:
    df_employee_rating.to_sql('employee_rating', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_rating)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'employee_rating'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'employee_rating'

# %%
# Tabla de employee_training:
df_employee_training = df[['employeenumber', 'trainingtimeslastyear']]
df_employee_training.columns = ['id_employee', 'trainingtimeslastyear']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_training.empty:
    df_employee_training.to_sql('employee_training', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_training)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'employee_training'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'employee_training'

# %%
# Tabla de employee_satisfaction:
df_employee_satisfaction = df[['employeenumber', 'environmentsatisfaction', 'jobsatisfaction', 'relationshipsatisfaction', 'worklifebalance']]
df_employee_satisfaction.columns = ['id_employee', 'environmentsatisfaction', 'jobsatisfaction', 'relationshipsatisfaction', 'worklifebalance']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_satisfaction.empty:
    df_employee_satisfaction.to_sql('employee_satisfaction', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_satisfaction)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'employee_satisfaction'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'employee_satisfaction'

# %%
# Tabla de employee_salary:
df_employee_salary = df[['employeenumber', 'salary', 'percentsalaryhike']]
df_employee_salary.columns = ['id_employee', 'salary', 'percentsalaryhike']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_salary.empty:
    df_employee_salary.to_sql('employee_salary', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_salary)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'employee_salary'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'employee_salary'

# %%
# Tabla de employee_conditions:
df_employee_conditions = df[['employeenumber', 'businesstravel', 'stockoptionlevel', 'standardhours', 'overtime', 'remotework']]
df_employee_conditions.columns = ['id_employee', 'businesstravel', 'stockoptionlevel', 'standardhours', 'overtime', 'remotework']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_conditions.empty:
    df_employee_conditions.to_sql('employee_conditions', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_conditions)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'employee_conditions'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'employee_conditions'

# %%
# Tabla de employee_company:
df_employee_company = df[['employeenumber', 'department', 'roledepartament', 'joblevel', 'jobrole', 'yearsatcompany', 'yearssincelastpromotion', 'yearswithcurrmanager']]
df_employee_company.columns = ['id_employee', 'department', 'roledepartament', 'joblevel', 'jobrole', 'yearsatcompany', 'yearssincelastpromotion', 'yearswithcurrmanager']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_employee_company.empty:
    df_employee_company.to_sql('employee_company', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_employee_company)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'employee_company'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'employee_company'

# %%
# Tabla de attrition:
df_attrition = df[['employeenumber', 'attrition']]
df_attrition.columns = ['id_employee', 'attrition']

id_employee_existentes = pd.read_sql("SELECT id_employee FROM employee_info", con=engine)

df_employee_info = df_employee_info[~df_employee_info['id_employee'].isin(id_employee_existentes['id_employee'])]

if not df_attrition.empty:
    df_attrition.to_sql('attrition', con=engine, if_exists='append', index=False)
    print(f"Insertados {len(df_attrition)} empleados nuevos.")
else:
    print("No hay empleados nuevos por insertar.")

print("Datos de empleados insertados en la tabla 'attrition'")
# Out:
# Insertados 1614 empleados nuevos.
# Datos de empleados insertados en la tabla 'attrition'
